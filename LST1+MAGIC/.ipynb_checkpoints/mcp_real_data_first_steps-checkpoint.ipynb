# %% [markdown]
# # Preparations

# %% [markdown]
# ## Running the notebook
#
# Make sure you can run the notebook:
# - if you work on the IT container, follow the instructions to run notebooks remotely. Make sure you have the environment `lst-school-2024-02-mcp` activated
# - if you work on PIC, same as above
# - if you work locally on your laptop, make sure the environment where you installed `magic-cta-pipe` is active
#
# The runbook can be found in the `magic-cta-pipe-analysis-school-2024` repository. If you did not clone it yet, do it now (from wherever you want to run it, IT, PIC, or locally):
#
# ```
# git clone https://github.com/cta-observatory/magic-cta-pipe-analysis-school-2024.git
# cd magic-cta-pipe-analysis-school-2024
# ```
#
# If you already have the repository cloned, just to be sure it is updated, do a pull:
#
# ```
# git pull
# ```
#
# This notebook should be there, i.e. called `mcp_real_data_first_steps.ipynb`.
#
# We can now proceed!

# %% [markdown]
# ## Check environment
#
# Check that the correct version of *magic-cta-pipe* is installed

# %%
import magicctapipe

print(magicctapipe.__version__)
# Out:
# 0.4.1

# %% [markdown]
# For you it should give 0.4.1 (in my case the version is something strange because I am using the development version)

# %% [markdown]
# # Joint data table
#
# Do you have joint data? The question is of course important. Usually you will know that there are joint data taken since it is usually reported in LST ELOGs. But the following link is more helpful:
#
# https://docs.google.com/spreadsheets/d/1Tya0tlK-3fuN6_vXOU5FwJruis5vBA9FALAPLFHOfBQ/edit#gid=1066216668
#
# You will find something like the following:
#
# <img src="joint_table.png">
#
# Several columns:
# - Date: the date of observation in LST convention i.e. the one of the evening when observations started (MAGIC uses the day after)
# - Source Name: this comes from MAGIC, but the ones used in LST are very similar
# - Conditions: dark/moon/twilight
# - Trigger: which trigger type was used in MAGIC, either L3T (standard), SumT (sum trigger), HaST (hardwa stereo trigger), L1_M1, L1_M2 (mono M1 or M2)
# - Stereo: if data taken in stereoscopic mode
# - HV: high voltage settings applied in MAGIC, either nominal or reduced
# - Min Zd, Max Zd: minimum/maximum zenith angle during the LST observation
# - LST Data runs: LST-1 data runs with joint data
# - MAGIC first/last run: which range of MAGIC runs correspond to the above LST data runs
# - Obs time: observation time on the same source (within 5deg)
# - Same wobble: observation time when the two systems were pointing at the same target within 0.1deg
#
# There is work ongoing by Ievgen and Volodymyr to have a LST-1 and LST-1+MAGIC database available, hopefully soon!
#
# Therefore, to know if you have joint data for a given source and night, just search in the table if there is an entry (or use the "query" sheet) for it (NB: date is in LST convention!).

# %% [markdown]
# # Where do you find the data?
#
# When you know which data you need, you want to analyze them. You can find the data in the IT container
# for MAGIC, only the runs which are tagged as joint according to the previous table are copied over.
#
# - For MAGIC, find the data in: `/fefs/onsite/common/MAGIC/data/[tel_id]/event/Calibrated/YYYY/MM/DD`
#    - tel_id can be either M1 or M2
#    - YYYY, MM, DD is year, month and day
#    - NOTE: day in MAGIC convention is one day after as the one in the LST convention!!! E.g. if LST data are from 2024-02-05, in MAGIC they will end up in the directory 2024/02/06
#
# - For MAGIC we use the so called “calibrated” files (~DL1a level in CTA data levels scheme)
#    - one file per subrun (one per telescope), numbers of subruns depending on trigger rate (fixed number of events per subrun); one run = one wobble position (if in wobble mode)
#    - they have the substring _Y_ in the name (other levels have a different letter)
#    - they are automatically generated by the OnSite Analysis (OSA i.e. the corresponding of LSTOSA of LST) starting from RAW data
#
# - For LST-1, we use DL1 data, you can find files in `/fefs/aswg/data/real/DL1/YYYYMMDD/v0.10/tailcut84/`
#    - version tag can change if data are reprocessed
#    - cleaning tag can also change (multiple tags with the same version tag)

# %% [markdown]
# # First analysis steps
#
# - We start from calibrated files because in the standard MAGIC analysis if in one of the telescope an event does not pass the filters (e.g. cleaning, or others), then the event is removed completely
#    - but with the three telescopes, that event may be seen by LST! So we want to keep them
#
# - Therefore, for real data, the first step of the joint analysis requires to:
#    - take MAGIC calibrated files, and process them to reach DL1b level
#    - cleaning+parameters computation (+pointing interpolation)
#    - via the `magic_calib_to_dl1` script
#
# - Then, MAGIC and LST-1 data are at the same data level
#    - we can find the (software) coincidence between the events
#    - via the `lst1_magic_event_coincidence` script
#
# - After the coincident events are found, one can use the multi-telescope (at least two) information to reconstruct the stereo parameters
#    - via the `lst1_magic_stereo_reco` script
#
#
# <img src="files/pipeline_scheme.png">

# %% [markdown]
# ## Data files for this notebook
#
#
# The data files needed for this notebook are available on the IT container and at PIC. If you work locally on your laptop, you should have them in some location on your pc.
#
# I selected a very small subsample from the Crab dataset used for the MAGIC+LST-1 performance paper, just to show how to run things. Below you find also subsections where I explain how to "extend" the apporach in a real analysis scenario.
#
# We start with the MAGIC input files.

# %%
# location of the MAGIC input files, choose the one it applies to you

magic_input_file_m1 = "/fefs/aswg/workspace/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/input/MAGIC/M1/20210214_M1_05094483.008_Y_CrabNebula-W0.40+215.root" # IT container
#magic_input_file_m1 = "/pnfs/pic.es/data/magic/Users/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/input/MAGIC/M1/20210214_M1_05094483.008_Y_CrabNebula-W0.40+215.root" # PIC
#magic_input_file_m1 = "/home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/input/MAGIC/M1/20210214_M1_05094483.008_Y_CrabNebula-W0.40+215.root" # your local pc

magic_input_file_m2 = "/fefs/aswg/workspace/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/input/MAGIC/M2/20210214_M2_05094483.008_Y_CrabNebula-W0.40+215.root" # IT container
#magic_input_file_m2 = "/pnfs/pic.es/data/magic/Users/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/input/MAGIC/M2/20210214_M2_05094483.008_Y_CrabNebula-W0.40+215.root" # PIC
#magic_input_file_m2 = "/home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/input/MAGIC/M2/20210214_M2_05094483.008_Y_CrabNebula-W0.40+215.root"

# %% [markdown]
# We want now to run the script `magic_calib_to_dl1`. We first check the help:

# %%
# !magic_calib_to_dl1 -h
# Out:
# usage: magic_calib_to_dl1 [-h] --input-file INPUT_FILE
#                           [--output-dir OUTPUT_DIR]
#                           [--config-file CONFIG_FILE] [--max-evt MAX_EVENTS]
#                           [--process-run]
#
# options:
#   -h, --help            show this help message and exit
#   --input-file INPUT_FILE, -i INPUT_FILE
#                         Path to an input MAGIC calibrated data file
#   --output-dir OUTPUT_DIR, -o OUTPUT_DIR
#                         Path to a directory where to save an output DL1 data
#                         file
#   --config-file CONFIG_FILE, -c CONFIG_FILE
#                         Path to a configuration file
#   --max-evt MAX_EVENTS, -m MAX_EVENTS
#                         Max. number of processed showers
#   --process-run         Process the events of all the subrun files at once

# %% [markdown]
# Most of the options are self-explanatory. The one requiring some explanation is `--process-run`. If this option is passed to the script when we call it, it will process all the subruns belonging to the one we give as input file, if present.
#
# In our case, the directories contain two subruns each. This means that `magic_calib_to_dl1` will process the two subruns together.
#
# Under the hood, `magic_calib_to_dl1` uses the class `MAGICEventSource` implemented in the `ctapipe_io_magic` module (https://github.com/cta-observatory/ctapipe_io_magic). This is the event source that reads MAGIC calibrated files and stores the information for each event in a `ctapipe` compliant data structure (the `ArrayEventContainer`).

# %% [markdown]
# We also need a configuration file. There is one provided with the hands-on.

# %%
config_file = "/fefs/aswg/workspace/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/conf/config.yaml" # IT container
#config_file = "/pnfs/pic.es/data/magic/Users/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/conf/config.yaml" # PIC
#config_file = "/home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/conf/config.yaml"
! cat $config_file
# Out:
# mc_tel_ids:
#     LST-1: 1
#     LST-2: 0
#     LST-3: 0
#     LST-4: 0
#     MAGIC-I: 2
#     MAGIC-II: 3
#
#
# LST:
#     image_extractor:
#         type: "LocalPeakWindowSum"
#         window_shift: 4
#         window_width: 8
#
#     increase_nsb:
#         use: true
#         extra_noise_in_dim_pixels: 1.27
#         extra_bias_in_dim_pixels: 0.665
#         transition_charge: 8
#         extra_noise_in_bright_pixels: 2.08
#
#     increase_psf:
#         use: false
#         fraction: null
#
#     tailcuts_clean:
#         picture_thresh: 8
#         boundary_thresh: 4
#         keep_isolated_pixels: false
#         min_number_picture_neighbors: 2
#
#     time_delta_cleaning:
#         use: true
#         min_number_neighbors: 1
#         time_limit: 2
#
#     dynamic_cleaning:
#         use: true
#         threshold: 267
#         fraction: 0.03
#
#     use_only_main_island: false
#
#
# MAGIC:
#     image_extractor:
#         type: "SlidingWindowMaxSum"
#         window_width: 5
#         apply_integration_correction: false
#
#     charge_correction:
#         use: true
#         factor: 1.143
#
#     magic_clean:
#         use_time: true
#         use_sum: true
#         picture_thresh: 6
#         boundary_thresh: 3.5
#         max_time_off: 4.5
#         max_time_diff: 1.5
#         find_hotpixels: true
#         pedestal_type: "from_extractor_rndm"
#
#     muon_ring:
#         thr_low: 25
#         tailcut: [12, 8]
#         ring_completeness_threshold: 25
#
#
# event_coincidence:
#     # History of the time offset between LST-1 and MAGIC
#     # before June 12 2021: -3.1 us
#     # June 13 2021 to Feb 28 2023: -6.5 us
#     # March 10 2023 to March 30 2023: -76039.3 us
#     # April 13 2023 to August 2023: -25.1 us
#     # after Sep 11 2023 : -6.2 us
#     timestamp_type_lst: "dragon_time"  # select "dragon_time", "tib_time" or "ucts_time"
#     window_half_width: "300 ns"
#     pre_offset_search: false
#     n_pre_offset_search_events: 100
#     time_offset:
#         start: "-10 us"
#         stop: "0 us"
#
#
# stereo_reco:
#     quality_cuts: "(intensity > 50) & (width > 0)"
#     theta_uplim: "6 arcmin"
#
#
# energy_regressor:
#     settings:
#         n_estimators: 150
#         criterion: "squared_error"
#         max_depth: 50
#         min_samples_split: 2
#         min_samples_leaf: 2
#         min_weight_fraction_leaf: 0.0
#         max_features: 1.0
#         max_leaf_nodes: null
#         min_impurity_decrease: 0.0
#         bootstrap: true
#         oob_score: false
#         n_jobs: 5
#         random_state: 42
#         verbose: 0
#         warm_start: false
#         ccp_alpha: 0.0
#         max_samples: null
#
#     features: [
#         "intensity",
#         "length",
#         "width",
#         "skewness",
#         "kurtosis",
#         "slope",
#         "intensity_width_2",
#         "h_max",
#         "impact",
#         "pointing_alt",
#         "pointing_az",
#     ]
#
#     gamma_offaxis:
#         min: null
#         max: null
#
#
# disp_regressor:
#     settings:
#         n_estimators: 150
#         criterion: "squared_error"
#         max_depth: 50
#         min_samples_split: 2
#         min_samples_leaf: 2
#         min_weight_fraction_leaf: 0.0
#         max_features: 1.0
#         max_leaf_nodes: null
#         min_impurity_decrease: 0.0
#         bootstrap: true
#         oob_score: false
#         n_jobs: 5
#         random_state: 42
#         verbose: 0
#         warm_start: false
#         ccp_alpha: 0.0
#         max_samples: null
#
#     features: [
#         "intensity",
#         "length",
#         "width",
#         "skewness",
#         "kurtosis",
#         "slope",
#         "intensity_width_2",
#         "h_max",
#         "impact",
#         "pointing_alt",
#         "pointing_az",
#     ]
#
#     gamma_offaxis:
#         min: null
#         max: null
#
#
# event_classifier:
#     settings:
#         n_estimators: 100
#         criterion: "gini"
#         max_depth: 100
#         min_samples_split: 2
#         min_samples_leaf: 2
#         min_weight_fraction_leaf: 0.0
#         max_features: "sqrt"
#         max_leaf_nodes: null
#         min_impurity_decrease: 0.0
#         bootstrap: true
#         oob_score: false
#         n_jobs: 5
#         random_state: 42
#         verbose: 0
#         warm_start: false
#         class_weight: null
#         ccp_alpha: 0.0
#         max_samples: null
#
#     features: [
#         "intensity",
#         "length",
#         "width",
#         "skewness",
#         "kurtosis",
#         "slope",
#         "intensity_width_2",
#         "h_max",
#         "impact",
#         "pointing_alt",
#         "pointing_az",
#     ]
#
#     gamma_offaxis:
#         min: null
#         max: null
#
#
# create_irf:
#     quality_cuts: "disp_diff_mean < 0.22"
#     event_type: "magic_only"  # select "software", "software_only_3tel", "magic_only" or "hardware"
#     weight_type_dl2: "intensity"  # select "simple", "variance" or "intensity"
#     obs_time_irf: "50 h"  # used when creating a background HDU
#
#     energy_bins:  # log space
#         start: "0.01 TeV"
#         stop: "1000 TeV"
#         n_edges: 26
#
#     migration_bins:  # log space
#         start: 0.2
#         stop: 5
#         n_edges: 31
#
#     fov_offset_bins:  # linear space, used for diffuse MCs
#         start: "0 deg"
#         stop: "1 deg"
#         n_edges: 6
#
#     source_offset_bins:  # linear space, used when creating PSF HDU
#         start: "0 deg"
#         stop: "1 deg"
#         n_edges: 101
#
#     bkg_fov_offset_bins:  # linear space, used when creating background HDU
#         start: "0 deg"
#         stop: "10 deg"
#         n_edges: 21
#
#     gammaness:
#         cut_type: "dynamic"  # select "global" or "dynamic"
#         global_cut_value: 0.8  # used for the global cut
#         efficiency: 0.9  # used for the dynamic cuts
#         min_cut: 0.05  # used for the dynamic cuts
#         max_cut: 0.85  # used for the dynamic cuts
#
#     theta:
#         cut_type: "dynamic"  # select "global" or "dynamic"
#         global_cut_value: "0.2 deg"  # used for the global cut
#         efficiency: 0.75  # used for the dynamic cuts
#         min_cut: "0.1 deg"  # used for the dynamic cuts
#         max_cut: "0.25 deg"  # used for the dynamic cuts
#
#
# dl2_to_dl3:
#     interpolation_method: "linear"  # select "nearest", "linear" or "cubic"
#     interpolation_scheme: "cosZd" # select "cosZdAz" or "cosZd"
#     max_distance: "45. deg"  # angle type Quantity, or comment out to remove the cut
#     source_name: "Crab"
#     source_ra: null  # used when the source name cannot be resolved
#     source_dec: null  # used when the source name cannot be resolved

# %% [markdown]
# The important parts of the configuration file for this script are:
#
# ```
# mc_tel_ids:
#     LST-1: 1
#     LST-2: 0
#     LST-3: 0
#     LST-4: 0
#     MAGIC-I: 2
#     MAGIC-II: 3
# ```
#
# This is needed to assign the telescope IDs for MAGIC and LST-1 (so also in later steps). If you use the standard MC used for joint analysis, the IDs in the default configuration file are the ones you need.
#
# The other important part is the one with the settings for the MAGIC cleaning:
#
# ```
# MAGIC:
#     image_extractor:
#         type: "SlidingWindowMaxSum"
#         window_width: 5
#         apply_integration_correction: false
#
#     charge_correction:
#         use: true
#         factor: 1.143
#
#     magic_clean:
#         use_time: true
#         use_sum: true
#         picture_thresh: 6
#         boundary_thresh: 3.5
#         max_time_off: 4.5
#         max_time_diff: 1.5
#         find_hotpixels: true
#         pedestal_type: "from_extractor_rndm"
# ```
#
# They are settings specific to MAGIC, no need to change them.

# %% [markdown]
# We create the output directory.

# %%
out_magic_to_dl1 = f"./output/dl0_to_dl1"
# !mkdir -p $out_magic_to_dl1

# %% [markdown]
# Now we run `magic_calib_to_dl1` for M1 and then M2.

# %%
# !magic_calib_to_dl1\
--input-file $magic_input_file_m1\
--output-dir $out_magic_to_dl1\
--config-file $config_file\
--process-run
# Out:
# ^C
# Traceback (most recent call last):
#   File "/fefs/aswg/software/conda/envs/lst-school-2024-02-mcp/bin/magic_calib_to_dl1", line 5, in <module>
#     from magicctapipe.scripts.lst1_magic.magic_calib_to_dl1 import main
#   File "/fefs/aswg/software/conda/envs/lst-school-2024-02-mcp/lib/python3.11/site-packages/magicctapipe/scripts/__init__.py", line 1, in <module>
#     from .lst1_magic import (
#   File "/fefs/aswg/software/conda/envs/lst-school-2024-02-mcp/lib/python3.11/site-packages/magicctapipe/scripts/lst1_magic/__init__.py", line 7, in <module>
#     from .lst1_magic_stereo_reco import stereo_reconstruction
#   File "/fefs/aswg/software/conda/envs/lst-school-2024-02-mcp/lib/python3.11/site-packages/magicctapipe/scripts/lst1_magic/lst1_magic_stereo_reco.py", line 49, in <module>
#     from ctapipe.reco import HillasReconstructor
#   File "/fefs/aswg/software/conda/envs/lst-school-2024-02-mcp/lib/python3.11/site-packages/ctapipe/reco/__init__.py", line 14, in <module>
#     from .sklearn import (
#   File "/fefs/aswg/software/conda/envs/lst-school-2024-02-mcp/lib/python3.11/site-packages/ctapipe/reco/sklearn.py", line 49, in <module>
#     SUPPORTED_CLASSIFIERS = dict(all_estimators("classifier"))
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/fefs/aswg/software/conda/envs/lst-school-2024-02-mcp/lib/python3.11/site-packages/sklearn/utils/discovery.py", line 63, in all_estimators
#     for _, module_name, _ in pkgutil.walk_packages(path=[root], prefix="sklearn."):
#   File "/fefs/aswg/software/conda/envs/lst-school-2024-02-mcp/lib/python3.11/pkgutil.py", line 92, in walk_packages
#     __import__(info.name)
#   File "/fefs/aswg/software/conda/envs/lst-school-2024-02-mcp/lib/python3.11/site-packages/sklearn/_build_utils/__init__.py", line 14, in <module>

# %%
# !magic_calib_to_dl1\
--input-file $magic_input_file_m2\
--output-dir $out_magic_to_dl1\
--config-file $config_file\
--process-run
# Out:
# Input file: /home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/input/MAGIC/M2/20210214_M2_05094483.008_Y_CrabNebula-W0.40+215.root
#
# Is simulation: False
#
# Observation ID: 5094483
# Telescope ID: 2
#
# Is stereo trigger: True
# Is SUM trigger: False
#
# The following files are found to read drive reports:
# /home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/input/MAGIC/M2/20210214_M2_05094483.008_Y_CrabNebula-W0.40+215.root
# /home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/input/MAGIC/M2/20210214_M2_05094483.009_Y_CrabNebula-W0.40+215.root
#
# Process run: True
#
# MAGIC image cleaning:
#     use_time: True
#     use_sum: True
#     picture_thresh: 6
#     boundary_thresh: 3.5
#     max_time_off: 4.5
#     max_time_diff: 1.5
#     find_hotpixels: True
#     pedestal_type: from_extractor_rndm
#
# Processing the events...
# Interpolating cosmic events information from 16 drive reports.
# Drive reports available from 2021-02-13 21:54:07.862 to 2021-02-13 21:56:14.006.
# 0 events
# --> 3 event (event ID: 101406) could not survive the image cleaning. Skipping...
# --> 8 event (event ID: 101412) could not survive the image cleaning. Skipping...
# --> 12 event (event ID: 101417) could not survive the image cleaning. Skipping...
# --> 39 event (event ID: 101444) could not survive the image cleaning. Skipping...
# --> 40 event (event ID: 101445) could not survive the image cleaning. Skipping...
# --> 41 event (event ID: 101446) could not survive the image cleaning. Skipping...
# --> 74 event (event ID: 101481) could not survive the image cleaning. Skipping...
# --> 76 event (event ID: 101483) could not survive the image cleaning. Skipping...
# --> 88 event (event ID: 101495) could not survive the image cleaning. Skipping...
# --> 92 event (event ID: 101499) could not survive the image cleaning. Skipping...
# --> 98 event (event ID: 101505) could not survive the image cleaning. Skipping...
# 100 events
# --> 100 event (event ID: 101507) could not survive the image cleaning. Skipping...
# --> 107 event (event ID: 101514) could not survive the image cleaning. Skipping...
# --> 116 event (event ID: 101523) could not survive the image cleaning. Skipping...
# --> 127 event (event ID: 101534) could not survive the image cleaning. Skipping...
# --> 141 event (event ID: 101549) could not survive the image cleaning. Skipping...
# --> 145 event (event ID: 101553) could not survive the image cleaning. Skipping...
# --> 148 event (event ID: 101556) could not survive the image cleaning. Skipping...
# --> 150 event (event ID: 101558) could not survive the image cleaning. Skipping...
# --> 153 event (event ID: 101561) could not survive the image cleaning. Skipping...
# --> 155 event (event ID: 101563) could not survive the image cleaning. Skipping...
# --> 167 event (event ID: 101575) could not survive the image cleaning. Skipping...
# --> 182 event (event ID: 101591) could not survive the image cleaning. Skipping...
# --> 186 event (event ID: 101595) could not survive the image cleaning. Skipping...
# --> 197 event (event ID: 101607) could not survive the image cleaning. Skipping...
# 200 events
# --> 204 event (event ID: 101615) could not survive the image cleaning. Skipping...
# --> 214 event (event ID: 101626) could not survive the image cleaning. Skipping...
# --> 217 event (event ID: 101629) could not survive the image cleaning. Skipping...
# --> 220 event (event ID: 101632) could not survive the image cleaning. Skipping...
# --> 222 event (event ID: 101635) could not survive the image cleaning. Skipping...
# --> 224 event (event ID: 101637) could not survive the image cleaning. Skipping...
# --> 234 event (event ID: 101647) could not survive the image cleaning. Skipping...
# --> 243 event (event ID: 101656) could not survive the image cleaning. Skipping...
# --> 249 event (event ID: 101662) could not survive the image cleaning. Skipping...
# --> 251 event (event ID: 101665) could not survive the image cleaning. Skipping...
# --> 252 event (event ID: 101666) could not survive the image cleaning. Skipping...
# --> 265 event (event ID: 101679) could not survive the image cleaning. Skipping...
# --> 267 event (event ID: 101681) could not survive the image cleaning. Skipping...
# --> 269 event (event ID: 101683) could not survive the image cleaning. Skipping...
# --> 287 event (event ID: 101702) could not survive the image cleaning. Skipping...
# --> 288 event (event ID: 101703) could not survive the image cleaning. Skipping...
# --> 293 event (event ID: 101708) could not survive the image cleaning. Skipping...
# 300 events
# --> 305 event (event ID: 101720) could not survive the image cleaning. Skipping...
# --> 310 event (event ID: 101725) could not survive the image cleaning. Skipping...
# --> 327 event (event ID: 101742) could not survive the image cleaning. Skipping...
# --> 342 event (event ID: 101759) could not survive the image cleaning. Skipping...
# --> 374 event (event ID: 101791) could not survive the image cleaning. Skipping...
# --> 378 event (event ID: 101795) could not survive the image cleaning. Skipping...
# 400 events
# --> 412 event (event ID: 101831) could not survive the image cleaning. Skipping...
# --> 417 event (event ID: 101836) failed to extract finite timing parameters. Skipping...
# --> 419 event (event ID: 101838) could not survive the image cleaning. Skipping...
# --> 420 event (event ID: 101839) could not survive the image cleaning. Skipping...
# --> 442 event (event ID: 101863) could not survive the image cleaning. Skipping...
# --> 453 event (event ID: 101874) could not survive the image cleaning. Skipping...
# --> 454 event (event ID: 101875) could not survive the image cleaning. Skipping...
# 500 events
# --> 501 event (event ID: 101923) could not survive the image cleaning. Skipping...
# --> 514 event (event ID: 101936) could not survive the image cleaning. Skipping...
# --> 519 event (event ID: 101942) could not survive the image cleaning. Skipping...
# --> 523 event (event ID: 101946) could not survive the image cleaning. Skipping...
# --> 534 event (event ID: 101959) could not survive the image cleaning. Skipping...
# --> 566 event (event ID: 101992) could not survive the image cleaning. Skipping...
# --> 571 event (event ID: 101997) could not survive the image cleaning. Skipping...
# --> 580 event (event ID: 102007) could not survive the image cleaning. Skipping...
# --> 593 event (event ID: 102020) could not survive the image cleaning. Skipping...
# 600 events
# --> 632 event (event ID: 102061) could not survive the image cleaning. Skipping...
# --> 635 event (event ID: 102064) could not survive the image cleaning. Skipping...
# --> 642 event (event ID: 102071) could not survive the image cleaning. Skipping...
# --> 652 event (event ID: 102083) could not survive the image cleaning. Skipping...
# --> 653 event (event ID: 102085) could not survive the image cleaning. Skipping...
# --> 661 event (event ID: 102093) could not survive the image cleaning. Skipping...
# --> 673 event (event ID: 102105) could not survive the image cleaning. Skipping...
# --> 675 event (event ID: 102107) could not survive the image cleaning. Skipping...
# --> 687 event (event ID: 102119) could not survive the image cleaning. Skipping...
# --> 693 event (event ID: 102128) could not survive the image cleaning. Skipping...
# --> 696 event (event ID: 102132) could not survive the image cleaning. Skipping...
# 700 events
# --> 714 event (event ID: 102151) could not survive the image cleaning. Skipping...
# --> 722 event (event ID: 102160) could not survive the image cleaning. Skipping...
# --> 732 event (event ID: 102171) could not survive the image cleaning. Skipping...
# --> 746 event (event ID: 102186) could not survive the image cleaning. Skipping...
# --> 747 event (event ID: 102187) could not survive the image cleaning. Skipping...
# --> 780 event (event ID: 102223) could not survive the image cleaning. Skipping...
# --> 794 event (event ID: 102239) could not survive the image cleaning. Skipping...
# --> 795 event (event ID: 102240) could not survive the image cleaning. Skipping...
# --> 799 event (event ID: 102244) could not survive the image cleaning. Skipping...
# 800 events
# --> 805 event (event ID: 102250) could not survive the image cleaning. Skipping...
# --> 807 event (event ID: 102253) could not survive the image cleaning. Skipping...
# --> 814 event (event ID: 102260) could not survive the image cleaning. Skipping...
# --> 822 event (event ID: 102268) could not survive the image cleaning. Skipping...
# --> 849 event (event ID: 102298) could not survive the image cleaning. Skipping...
# --> 855 event (event ID: 102304) could not survive the image cleaning. Skipping...
# --> 884 event (event ID: 102334) could not survive the image cleaning. Skipping...
# --> 897 event (event ID: 102347) could not survive the image cleaning. Skipping...
# 900 events
# --> 909 event (event ID: 102360) could not survive the image cleaning. Skipping...
# --> 932 event (event ID: 102384) could not survive the image cleaning. Skipping...
# --> 940 event (event ID: 102394) could not survive the image cleaning. Skipping...
# --> 948 event (event ID: 102402) could not survive the image cleaning. Skipping...
# --> 949 event (event ID: 102403) could not survive the image cleaning. Skipping...
# --> 977 event (event ID: 102433) could not survive the image cleaning. Skipping...
# --> 982 event (event ID: 102438) could not survive the image cleaning. Skipping...
# --> 984 event (event ID: 102440) could not survive the image cleaning. Skipping...
# --> 996 event (event ID: 102452) could not survive the image cleaning. Skipping...
# 1000 events
# --> 1003 event (event ID: 102459) could not survive the image cleaning. Skipping...
# --> 1005 event (event ID: 102461) could not survive the image cleaning. Skipping...
# --> 1028 event (event ID: 102484) could not survive the image cleaning. Skipping...
# --> 1030 event (event ID: 102486) could not survive the image cleaning. Skipping...
# --> 1034 event (event ID: 102491) could not survive the image cleaning. Skipping...
# --> 1040 event (event ID: 102498) could not survive the image cleaning. Skipping...
# --> 1042 event (event ID: 102500) could not survive the image cleaning. Skipping...
# --> 1062 event (event ID: 102523) could not survive the image cleaning. Skipping...
# --> 1063 event (event ID: 102524) could not survive the image cleaning. Skipping...
# --> 1064 event (event ID: 102525) could not survive the image cleaning. Skipping...
# --> 1086 event (event ID: 102550) could not survive the image cleaning. Skipping...
# --> 1092 event (event ID: 102557) could not survive the image cleaning. Skipping...
# --> 1093 event (event ID: 102558) could not survive the image cleaning. Skipping...
# 1100 events
# --> 1105 event (event ID: 102572) could not survive the image cleaning. Skipping...
# --> 1106 event (event ID: 102573) could not survive the image cleaning. Skipping...
# --> 1111 event (event ID: 102578) could not survive the image cleaning. Skipping...
# --> 1112 event (event ID: 102579) could not survive the image cleaning. Skipping...
# --> 1135 event (event ID: 102604) could not survive the image cleaning. Skipping...
# --> 1147 event (event ID: 102617) could not survive the image cleaning. Skipping...
# --> 1153 event (event ID: 102623) could not survive the image cleaning. Skipping...
# --> 1159 event (event ID: 102629) could not survive the image cleaning. Skipping...
# --> 1163 event (event ID: 102633) could not survive the image cleaning. Skipping...
# --> 1164 event (event ID: 102634) could not survive the image cleaning. Skipping...
# --> 1171 event (event ID: 102641) could not survive the image cleaning. Skipping...
# --> 1177 event (event ID: 102647) could not survive the image cleaning. Skipping...
# --> 1178 event (event ID: 102648) could not survive the image cleaning. Skipping...
# --> 1185 event (event ID: 102655) could not survive the image cleaning. Skipping...
# --> 1188 event (event ID: 102659) could not survive the image cleaning. Skipping...
# --> 1192 event (event ID: 102663) could not survive the image cleaning. Skipping...
# 1200 events
# --> 1203 event (event ID: 102674) could not survive the image cleaning. Skipping...
# --> 1214 event (event ID: 102685) could not survive the image cleaning. Skipping...
# --> 1217 event (event ID: 102688) could not survive the image cleaning. Skipping...
# --> 1231 event (event ID: 102703) could not survive the image cleaning. Skipping...
# --> 1248 event (event ID: 102721) could not survive the image cleaning. Skipping...
# --> 1265 event (event ID: 102738) could not survive the image cleaning. Skipping...
# --> 1272 event (event ID: 102746) could not survive the image cleaning. Skipping...
# --> 1285 event (event ID: 102759) could not survive the image cleaning. Skipping...
# --> 1286 event (event ID: 102760) could not survive the image cleaning. Skipping...
# --> 1298 event (event ID: 102772) could not survive the image cleaning. Skipping...
# 1300 events
# --> 1309 event (event ID: 102783) could not survive the image cleaning. Skipping...
# --> 1310 event (event ID: 102784) could not survive the image cleaning. Skipping...
# --> 1321 event (event ID: 102796) could not survive the image cleaning. Skipping...
# --> 1322 event (event ID: 102798) could not survive the image cleaning. Skipping...
# --> 1323 event (event ID: 102799) could not survive the image cleaning. Skipping...
# --> 1328 event (event ID: 102804) could not survive the image cleaning. Skipping...
# --> 1340 event (event ID: 102816) failed to extract finite timing parameters. Skipping...
# 1400 events
# --> 1418 event (event ID: 102898) could not survive the image cleaning. Skipping...
# --> 1419 event (event ID: 102899) could not survive the image cleaning. Skipping...
# --> 1424 event (event ID: 102904) could not survive the image cleaning. Skipping...
# --> 1437 event (event ID: 102918) could not survive the image cleaning. Skipping...
# --> 1448 event (event ID: 102929) could not survive the image cleaning. Skipping...
# --> 1454 event (event ID: 102935) could not survive the image cleaning. Skipping...
# --> 1456 event (event ID: 102937) could not survive the image cleaning. Skipping...
# --> 1457 event (event ID: 102938) could not survive the image cleaning. Skipping...
# --> 1468 event (event ID: 102952) could not survive the image cleaning. Skipping...
# --> 1499 event (event ID: 102985) could not survive the image cleaning. Skipping...
# 1500 events
# --> 1509 event (event ID: 102995) could not survive the image cleaning. Skipping...
# --> 1511 event (event ID: 102997) could not survive the image cleaning. Skipping...
# --> 1538 event (event ID: 103027) could not survive the image cleaning. Skipping...
# --> 1541 event (event ID: 103030) could not survive the image cleaning. Skipping...
# --> 1542 event (event ID: 103031) could not survive the image cleaning. Skipping...
# --> 1548 event (event ID: 103037) could not survive the image cleaning. Skipping...
# --> 1549 event (event ID: 103038) could not survive the image cleaning. Skipping...
# --> 1574 event (event ID: 103063) could not survive the image cleaning. Skipping...
# --> 1581 event (event ID: 103071) could not survive the image cleaning. Skipping...
# --> 1583 event (event ID: 103073) could not survive the image cleaning. Skipping...
# 1600 events
# --> 1605 event (event ID: 103098) could not survive the image cleaning. Skipping...
# --> 1620 event (event ID: 103114) could not survive the image cleaning. Skipping...
# --> 1623 event (event ID: 103117) could not survive the image cleaning. Skipping...
# --> 1627 event (event ID: 103121) could not survive the image cleaning. Skipping...
# --> 1636 event (event ID: 103130) could not survive the image cleaning. Skipping...
# --> 1641 event (event ID: 103135) could not survive the image cleaning. Skipping...
# --> 1644 event (event ID: 103138) could not survive the image cleaning. Skipping...
# --> 1647 event (event ID: 103141) could not survive the image cleaning. Skipping...
# --> 1668 event (event ID: 103162) could not survive the image cleaning. Skipping...
# --> 1671 event (event ID: 103165) could not survive the image cleaning. Skipping...
# --> 1683 event (event ID: 103177) could not survive the image cleaning. Skipping...
# --> 1691 event (event ID: 103187) could not survive the image cleaning. Skipping...
# --> 1693 event (event ID: 103189) could not survive the image cleaning. Skipping...
# 1700 events
# --> 1711 event (event ID: 103210) could not survive the image cleaning. Skipping...
# --> 1721 event (event ID: 103221) could not survive the image cleaning. Skipping...
# --> 1740 event (event ID: 103241) could not survive the image cleaning. Skipping...
# --> 1754 event (event ID: 103255) could not survive the image cleaning. Skipping...
# --> 1791 event (event ID: 103293) could not survive the image cleaning. Skipping...
# --> 1792 event (event ID: 103294) could not survive the image cleaning. Skipping...
# 1800 events
# --> 1803 event (event ID: 103305) could not survive the image cleaning. Skipping...
# --> 1805 event (event ID: 103307) could not survive the image cleaning. Skipping...
# --> 1807 event (event ID: 103309) could not survive the image cleaning. Skipping...
# --> 1815 event (event ID: 103317) could not survive the image cleaning. Skipping...
# --> 1832 event (event ID: 103334) could not survive the image cleaning. Skipping...
# --> 1869 event (event ID: 103374) could not survive the image cleaning. Skipping...
# --> 1872 event (event ID: 103377) could not survive the image cleaning. Skipping...
# --> 1881 event (event ID: 103386) could not survive the image cleaning. Skipping...
# --> 1898 event (event ID: 103404) could not survive the image cleaning. Skipping...
# 1900 events
# --> 1901 event (event ID: 103409) could not survive the image cleaning. Skipping...
# --> 1916 event (event ID: 103424) could not survive the image cleaning. Skipping...
# --> 1927 event (event ID: 103435) could not survive the image cleaning. Skipping...
# --> 1931 event (event ID: 103440) could not survive the image cleaning. Skipping...
# --> 1954 event (event ID: 103464) could not survive the image cleaning. Skipping...
# --> 1972 event (event ID: 103482) could not survive the image cleaning. Skipping...
# --> 1984 event (event ID: 103494) could not survive the image cleaning. Skipping...
# 2000 events
# --> 2006 event (event ID: 103520) could not survive the image cleaning. Skipping...
# --> 2014 event (event ID: 103528) could not survive the image cleaning. Skipping...
# --> 2015 event (event ID: 103529) could not survive the image cleaning. Skipping...
# --> 2016 event (event ID: 103530) could not survive the image cleaning. Skipping...
# --> 2017 event (event ID: 103531) could not survive the image cleaning. Skipping...
# --> 2019 event (event ID: 103533) could not survive the image cleaning. Skipping...
# --> 2027 event (event ID: 103541) could not survive the image cleaning. Skipping...
# --> 2036 event (event ID: 103551) could not survive the image cleaning. Skipping...
# --> 2037 event (event ID: 103552) could not survive the image cleaning. Skipping...
# --> 2039 event (event ID: 103554) could not survive the image cleaning. Skipping...
# --> 2048 event (event ID: 103563) could not survive the image cleaning. Skipping...
# --> 2053 event (event ID: 103568) could not survive the image cleaning. Skipping...
# --> 2055 event (event ID: 103570) could not survive the image cleaning. Skipping...
# --> 2057 event (event ID: 103572) could not survive the image cleaning. Skipping...
# --> 2083 event (event ID: 103599) could not survive the image cleaning. Skipping...
# --> 2084 event (event ID: 103600) could not survive the image cleaning. Skipping...
# --> 2085 event (event ID: 103601) could not survive the image cleaning. Skipping...
# --> 2096 event (event ID: 103613) could not survive the image cleaning. Skipping...
# 2100 events
# --> 2135 event (event ID: 103655) could not survive the image cleaning. Skipping...
# --> 2157 event (event ID: 103679) could not survive the image cleaning. Skipping...
# --> 2158 event (event ID: 103680) could not survive the image cleaning. Skipping...
# --> 2167 event (event ID: 103689) could not survive the image cleaning. Skipping...
# --> 2172 event (event ID: 103695) could not survive the image cleaning. Skipping...
# --> 2174 event (event ID: 103697) could not survive the image cleaning. Skipping...
# --> 2176 event (event ID: 103699) could not survive the image cleaning. Skipping...
# --> 2183 event (event ID: 103706) could not survive the image cleaning. Skipping...
# --> 2184 event (event ID: 103707) could not survive the image cleaning. Skipping...
# --> 2189 event (event ID: 103712) could not survive the image cleaning. Skipping...
# 2200 events
# --> 2202 event (event ID: 103727) could not survive the image cleaning. Skipping...
# --> 2207 event (event ID: 103732) could not survive the image cleaning. Skipping...
# --> 2215 event (event ID: 103741) could not survive the image cleaning. Skipping...
# --> 2223 event (event ID: 103749) could not survive the image cleaning. Skipping...
# --> 2229 event (event ID: 103755) could not survive the image cleaning. Skipping...
# --> 2231 event (event ID: 103757) could not survive the image cleaning. Skipping...
# --> 2238 event (event ID: 103764) could not survive the image cleaning. Skipping...
# --> 2240 event (event ID: 103766) could not survive the image cleaning. Skipping...
# --> 2273 event (event ID: 103799) could not survive the image cleaning. Skipping...
# --> 2281 event (event ID: 103807) could not survive the image cleaning. Skipping...
# --> 2283 event (event ID: 103809) could not survive the image cleaning. Skipping...
# --> 2286 event (event ID: 103812) could not survive the image cleaning. Skipping...
# --> 2288 event (event ID: 103814) could not survive the image cleaning. Skipping...
# --> 2289 event (event ID: 103815) could not survive the image cleaning. Skipping...
# --> 2298 event (event ID: 103824) could not survive the image cleaning. Skipping...
# 2300 events
# --> 2305 event (event ID: 103831) could not survive the image cleaning. Skipping...
# --> 2306 event (event ID: 103832) could not survive the image cleaning. Skipping...
# --> 2325 event (event ID: 103852) could not survive the image cleaning. Skipping...
# --> 2331 event (event ID: 103858) could not survive the image cleaning. Skipping...
# --> 2332 event (event ID: 103859) could not survive the image cleaning. Skipping...
# --> 2359 event (event ID: 103887) could not survive the image cleaning. Skipping...
# --> 2371 event (event ID: 103899) could not survive the image cleaning. Skipping...
# --> 2385 event (event ID: 103914) could not survive the image cleaning. Skipping...
# --> 2386 event (event ID: 103915) could not survive the image cleaning. Skipping...
# --> 2390 event (event ID: 103919) could not survive the image cleaning. Skipping...
# --> 2395 event (event ID: 103924) could not survive the image cleaning. Skipping...
# 2400 events
# --> 2405 event (event ID: 103934) could not survive the image cleaning. Skipping...
# --> 2413 event (event ID: 103942) failed to extract finite timing parameters. Skipping...
# --> 2421 event (event ID: 103950) could not survive the image cleaning. Skipping...
# --> 2440 event (event ID: 103970) could not survive the image cleaning. Skipping...
# --> 2449 event (event ID: 103982) could not survive the image cleaning. Skipping...
# --> 2452 event (event ID: 103985) could not survive the image cleaning. Skipping...
# --> 2455 event (event ID: 103988) could not survive the image cleaning. Skipping...
# --> 2464 event (event ID: 103997) could not survive the image cleaning. Skipping...
# --> 2473 event (event ID: 104007) could not survive the image cleaning. Skipping...
# --> 2476 event (event ID: 104011) could not survive the image cleaning. Skipping...
# --> 2484 event (event ID: 104020) could not survive the image cleaning. Skipping...
# --> 2487 event (event ID: 104023) could not survive the image cleaning. Skipping...
# --> 2488 event (event ID: 104024) could not survive the image cleaning. Skipping...
# 2500 events
# --> 2501 event (event ID: 104037) could not survive the image cleaning. Skipping...
# --> 2504 event (event ID: 104040) could not survive the image cleaning. Skipping...
# --> 2507 event (event ID: 104044) could not survive the image cleaning. Skipping...
# --> 2522 event (event ID: 104060) could not survive the image cleaning. Skipping...
# --> 2526 event (event ID: 104064) could not survive the image cleaning. Skipping...
# --> 2532 event (event ID: 104070) could not survive the image cleaning. Skipping...
# --> 2534 event (event ID: 104072) could not survive the image cleaning. Skipping...
# --> 2539 event (event ID: 104077) could not survive the image cleaning. Skipping...
# --> 2543 event (event ID: 104081) could not survive the image cleaning. Skipping...
# --> 2547 event (event ID: 104085) could not survive the image cleaning. Skipping...
# --> 2575 event (event ID: 104114) could not survive the image cleaning. Skipping...
# --> 2584 event (event ID: 104123) could not survive the image cleaning. Skipping...
# --> 2593 event (event ID: 104132) could not survive the image cleaning. Skipping...
# 2600 events
# --> 2602 event (event ID: 104143) could not survive the image cleaning. Skipping...
# --> 2603 event (event ID: 104144) could not survive the image cleaning. Skipping...
# --> 2606 event (event ID: 104147) could not survive the image cleaning. Skipping...
# --> 2608 event (event ID: 104149) could not survive the image cleaning. Skipping...
# --> 2618 event (event ID: 104160) could not survive the image cleaning. Skipping...
# --> 2620 event (event ID: 104162) could not survive the image cleaning. Skipping...
# --> 2659 event (event ID: 104204) could not survive the image cleaning. Skipping...
# --> 2670 event (event ID: 104216) could not survive the image cleaning. Skipping...
# --> 2686 event (event ID: 104233) could not survive the image cleaning. Skipping...
# --> 2687 event (event ID: 104234) could not survive the image cleaning. Skipping...
# --> 2691 event (event ID: 104238) could not survive the image cleaning. Skipping...
# --> 2698 event (event ID: 104246) could not survive the image cleaning. Skipping...
# 2700 events
# --> 2711 event (event ID: 104261) could not survive the image cleaning. Skipping...
# --> 2712 event (event ID: 104262) could not survive the image cleaning. Skipping...
# --> 2720 event (event ID: 104272) could not survive the image cleaning. Skipping...
# --> 2734 event (event ID: 104287) could not survive the image cleaning. Skipping...
# --> 2739 event (event ID: 104292) could not survive the image cleaning. Skipping...
# --> 2740 event (event ID: 104293) could not survive the image cleaning. Skipping...
# --> 2746 event (event ID: 104299) could not survive the image cleaning. Skipping...
# --> 2748 event (event ID: 104301) could not survive the image cleaning. Skipping...
# --> 2755 event (event ID: 104308) could not survive the image cleaning. Skipping...
# --> 2756 event (event ID: 104309) could not survive the image cleaning. Skipping...
# --> 2759 event (event ID: 104312) could not survive the image cleaning. Skipping...
# --> 2760 event (event ID: 104313) could not survive the image cleaning. Skipping...
# --> 2761 event (event ID: 104314) could not survive the image cleaning. Skipping...
# --> 2769 event (event ID: 104323) could not survive the image cleaning. Skipping...
# --> 2777 event (event ID: 104331) could not survive the image cleaning. Skipping...
# --> 2791 event (event ID: 104347) could not survive the image cleaning. Skipping...
# --> 2794 event (event ID: 104350) could not survive the image cleaning. Skipping...
# 2800 events
# --> 2807 event (event ID: 104366) could not survive the image cleaning. Skipping...
# --> 2809 event (event ID: 104368) could not survive the image cleaning. Skipping...
# --> 2812 event (event ID: 104373) could not survive the image cleaning. Skipping...
# --> 2819 event (event ID: 104380) could not survive the image cleaning. Skipping...
# --> 2820 event (event ID: 104381) could not survive the image cleaning. Skipping...
# --> 2822 event (event ID: 104383) could not survive the image cleaning. Skipping...
# --> 2836 event (event ID: 104397) could not survive the image cleaning. Skipping...
# --> 2838 event (event ID: 104399) could not survive the image cleaning. Skipping...
# --> 2840 event (event ID: 104401) could not survive the image cleaning. Skipping...
# --> 2848 event (event ID: 104410) could not survive the image cleaning. Skipping...
# --> 2856 event (event ID: 104419) could not survive the image cleaning. Skipping...
# --> 2862 event (event ID: 104425) could not survive the image cleaning. Skipping...
# --> 2874 event (event ID: 104439) could not survive the image cleaning. Skipping...
# --> 2880 event (event ID: 104445) could not survive the image cleaning. Skipping...
# --> 2881 event (event ID: 104447) could not survive the image cleaning. Skipping...
# --> 2882 event (event ID: 104448) could not survive the image cleaning. Skipping...
# --> 2884 event (event ID: 104451) could not survive the image cleaning. Skipping...
# --> 2886 event (event ID: 104453) could not survive the image cleaning. Skipping...
# --> 2887 event (event ID: 104455) could not survive the image cleaning. Skipping...
# --> 2889 event (event ID: 104458) could not survive the image cleaning. Skipping...
# 2900 events
# --> 2900 event (event ID: 104475) could not survive the image cleaning. Skipping...
# --> 2901 event (event ID: 104477) could not survive the image cleaning. Skipping...
# --> 2902 event (event ID: 104478) could not survive the image cleaning. Skipping...
# --> 2904 event (event ID: 104480) could not survive the image cleaning. Skipping...
# --> 2906 event (event ID: 104482) could not survive the image cleaning. Skipping...
# --> 2908 event (event ID: 104484) could not survive the image cleaning. Skipping...
# --> 2913 event (event ID: 104491) could not survive the image cleaning. Skipping...
# --> 2916 event (event ID: 104496) could not survive the image cleaning. Skipping...
# --> 2921 event (event ID: 104504) could not survive the image cleaning. Skipping...
# --> 2926 event (event ID: 104513) could not survive the image cleaning. Skipping...
# --> 2929 event (event ID: 104516) could not survive the image cleaning. Skipping...
# --> 2931 event (event ID: 104519) could not survive the image cleaning. Skipping...
# --> 2933 event (event ID: 104522) could not survive the image cleaning. Skipping...
# --> 2934 event (event ID: 104524) could not survive the image cleaning. Skipping...
# --> 2942 event (event ID: 104537) could not survive the image cleaning. Skipping...
# --> 2948 event (event ID: 104543) could not survive the image cleaning. Skipping...
# --> 2949 event (event ID: 104545) could not survive the image cleaning. Skipping...
# --> 2955 event (event ID: 104553) could not survive the image cleaning. Skipping...
# --> 2957 event (event ID: 104555) could not survive the image cleaning. Skipping...
# --> 2958 event (event ID: 104556) could not survive the image cleaning. Skipping...
# --> 2962 event (event ID: 104560) could not survive the image cleaning. Skipping...
# --> 2964 event (event ID: 104563) could not survive the image cleaning. Skipping...
# --> 2966 event (event ID: 104567) could not survive the image cleaning. Skipping...
# --> 2969 event (event ID: 104571) could not survive the image cleaning. Skipping...
# --> 2981 event (event ID: 104585) could not survive the image cleaning. Skipping...
# --> 2989 event (event ID: 104595) could not survive the image cleaning. Skipping...
# --> 2991 event (event ID: 104597) could not survive the image cleaning. Skipping...
# 3000 events
# --> 3000 event (event ID: 104607) could not survive the image cleaning. Skipping...
# --> 3004 event (event ID: 104611) could not survive the image cleaning. Skipping...
# --> 3005 event (event ID: 104612) could not survive the image cleaning. Skipping...
# --> 3007 event (event ID: 104614) could not survive the image cleaning. Skipping...
# --> 3010 event (event ID: 104617) could not survive the image cleaning. Skipping...
# --> 3015 event (event ID: 104622) could not survive the image cleaning. Skipping...
# --> 3017 event (event ID: 104624) could not survive the image cleaning. Skipping...
# --> 3019 event (event ID: 104627) could not survive the image cleaning. Skipping...
# --> 3029 event (event ID: 104638) could not survive the image cleaning. Skipping...
# --> 3034 event (event ID: 104643) could not survive the image cleaning. Skipping...
# --> 3040 event (event ID: 104650) could not survive the image cleaning. Skipping...
# --> 3041 event (event ID: 104651) could not survive the image cleaning. Skipping...
# --> 3044 event (event ID: 104654) could not survive the image cleaning. Skipping...
# --> 3051 event (event ID: 104662) could not survive the image cleaning. Skipping...
# --> 3055 event (event ID: 104667) could not survive the image cleaning. Skipping...
# --> 3061 event (event ID: 104673) could not survive the image cleaning. Skipping...
# --> 3067 event (event ID: 104686) could not survive the image cleaning. Skipping...
# --> 3068 event (event ID: 104687) could not survive the image cleaning. Skipping...
# --> 3072 event (event ID: 104693) could not survive the image cleaning. Skipping...
# --> 3074 event (event ID: 104696) could not survive the image cleaning. Skipping...
# --> 3077 event (event ID: 104701) could not survive the image cleaning. Skipping...
# --> 3078 event (event ID: 104705) could not survive the image cleaning. Skipping...
# --> 3087 event (event ID: 104715) could not survive the image cleaning. Skipping...
# --> 3091 event (event ID: 104720) could not survive the image cleaning. Skipping...
# --> 3092 event (event ID: 104722) could not survive the image cleaning. Skipping...
# --> 3095 event (event ID: 104729) could not survive the image cleaning. Skipping...
# --> 3097 event (event ID: 104731) could not survive the image cleaning. Skipping...
# --> 3098 event (event ID: 104732) could not survive the image cleaning. Skipping...
# --> 3099 event (event ID: 104733) could not survive the image cleaning. Skipping...
# 3100 events
# --> 3104 event (event ID: 104738) could not survive the image cleaning. Skipping...
# --> 3106 event (event ID: 104740) could not survive the image cleaning. Skipping...
# --> 3116 event (event ID: 104753) could not survive the image cleaning. Skipping...
# --> 3119 event (event ID: 104757) could not survive the image cleaning. Skipping...
# --> 3120 event (event ID: 104758) could not survive the image cleaning. Skipping...
# --> 3124 event (event ID: 104762) could not survive the image cleaning. Skipping...
# --> 3125 event (event ID: 104764) could not survive the image cleaning. Skipping...
# --> 3131 event (event ID: 104771) failed to extract finite timing parameters. Skipping...
# --> 3134 event (event ID: 104774) could not survive the image cleaning. Skipping...
# --> 3139 event (event ID: 104781) could not survive the image cleaning. Skipping...
# --> 3140 event (event ID: 104783) failed to extract finite timing parameters. Skipping...
# --> 3143 event (event ID: 104788) could not survive the image cleaning. Skipping...
# --> 3144 event (event ID: 104789) could not survive the image cleaning. Skipping...
# --> 3145 event (event ID: 104790) could not survive the image cleaning. Skipping...
# --> 3146 event (event ID: 104792) could not survive the image cleaning. Skipping...
# --> 3147 event (event ID: 104794) could not survive the image cleaning. Skipping...
# --> 3148 event (event ID: 104796) could not survive the image cleaning. Skipping...
# --> 3150 event (event ID: 104799) could not survive the image cleaning. Skipping...
# --> 3153 event (event ID: 104802) could not survive the image cleaning. Skipping...
# --> 3159 event (event ID: 104809) could not survive the image cleaning. Skipping...
# --> 3161 event (event ID: 104811) could not survive the image cleaning. Skipping...
# --> 3167 event (event ID: 104818) could not survive the image cleaning. Skipping...
# --> 3169 event (event ID: 104821) could not survive the image cleaning. Skipping...
# --> 3172 event (event ID: 104825) could not survive the image cleaning. Skipping...
# --> 3173 event (event ID: 104826) could not survive the image cleaning. Skipping...
# --> 3176 event (event ID: 104829) could not survive the image cleaning. Skipping...
# --> 3177 event (event ID: 104830) could not survive the image cleaning. Skipping...
# --> 3183 event (event ID: 104836) could not survive the image cleaning. Skipping...
# --> 3186 event (event ID: 104840) could not survive the image cleaning. Skipping...
# --> 3191 event (event ID: 104848) could not survive the image cleaning. Skipping...
# --> 3193 event (event ID: 104850) could not survive the image cleaning. Skipping...
# --> 3194 event (event ID: 104851) could not survive the image cleaning. Skipping...
# --> 3195 event (event ID: 104853) could not survive the image cleaning. Skipping...
# 3200 events
# --> 3202 event (event ID: 104862) could not survive the image cleaning. Skipping...
# --> 3207 event (event ID: 104867) could not survive the image cleaning. Skipping...
# --> 3208 event (event ID: 104868) could not survive the image cleaning. Skipping...
# --> 3212 event (event ID: 104872) could not survive the image cleaning. Skipping...
# --> 3216 event (event ID: 104876) could not survive the image cleaning. Skipping...
# --> 3227 event (event ID: 104889) could not survive the image cleaning. Skipping...
# --> 3230 event (event ID: 104892) could not survive the image cleaning. Skipping...
# --> 3234 event (event ID: 104896) could not survive the image cleaning. Skipping...
# --> 3237 event (event ID: 104899) could not survive the image cleaning. Skipping...
# --> 3238 event (event ID: 104900) could not survive the image cleaning. Skipping...
# --> 3240 event (event ID: 104902) could not survive the image cleaning. Skipping...
# --> 3243 event (event ID: 104906) could not survive the image cleaning. Skipping...
# --> 3248 event (event ID: 104911) could not survive the image cleaning. Skipping...
# --> 3254 event (event ID: 104920) could not survive the image cleaning. Skipping...
# --> 3261 event (event ID: 104927) could not survive the image cleaning. Skipping...
# --> 3262 event (event ID: 104928) could not survive the image cleaning. Skipping...
# --> 3263 event (event ID: 104930) could not survive the image cleaning. Skipping...
# --> 3273 event (event ID: 104940) could not survive the image cleaning. Skipping...
# --> 3275 event (event ID: 104944) could not survive the image cleaning. Skipping...
# --> 3281 event (event ID: 104955) could not survive the image cleaning. Skipping...
# --> 3287 event (event ID: 104963) could not survive the image cleaning. Skipping...
# --> 3289 event (event ID: 104966) could not survive the image cleaning. Skipping...
# --> 3297 event (event ID: 104976) could not survive the image cleaning. Skipping...
# 3300 events
# --> 3301 event (event ID: 104983) could not survive the image cleaning. Skipping...
# --> 3304 event (event ID: 104988) could not survive the image cleaning. Skipping...
# --> 3309 event (event ID: 104995) could not survive the image cleaning. Skipping...
# --> 3311 event (event ID: 105000) could not survive the image cleaning. Skipping...
# --> 3312 event (event ID: 105001) could not survive the image cleaning. Skipping...
# --> 3316 event (event ID: 105005) could not survive the image cleaning. Skipping...
# --> 3319 event (event ID: 105008) could not survive the image cleaning. Skipping...
# --> 3321 event (event ID: 105011) could not survive the image cleaning. Skipping...
# --> 3322 event (event ID: 105013) could not survive the image cleaning. Skipping...
# --> 3328 event (event ID: 105020) could not survive the image cleaning. Skipping...
# --> 3331 event (event ID: 105023) could not survive the image cleaning. Skipping...
# --> 3334 event (event ID: 105026) could not survive the image cleaning. Skipping...
# --> 3336 event (event ID: 105028) could not survive the image cleaning. Skipping...
# --> 3340 event (event ID: 105033) could not survive the image cleaning. Skipping...
# --> 3344 event (event ID: 105037) failed to extract finite timing parameters. Skipping...
# --> 3348 event (event ID: 105041) could not survive the image cleaning. Skipping...
# --> 3351 event (event ID: 105044) could not survive the image cleaning. Skipping...
# --> 3353 event (event ID: 105046) could not survive the image cleaning. Skipping...
# --> 3356 event (event ID: 105053) could not survive the image cleaning. Skipping...
# --> 3359 event (event ID: 105057) could not survive the image cleaning. Skipping...
# --> 3360 event (event ID: 105059) could not survive the image cleaning. Skipping...
# --> 3368 event (event ID: 105069) could not survive the image cleaning. Skipping...
# --> 3372 event (event ID: 105075) could not survive the image cleaning. Skipping...
# --> 3373 event (event ID: 105077) could not survive the image cleaning. Skipping...
# --> 3377 event (event ID: 105083) could not survive the image cleaning. Skipping...
# --> 3378 event (event ID: 105086) could not survive the image cleaning. Skipping...
# --> 3386 event (event ID: 105099) could not survive the image cleaning. Skipping...
# 3400 events
# --> 3411 event (event ID: 105134) failed to extract finite timing parameters. Skipping...
# --> 3420 event (event ID: 105146) could not survive the image cleaning. Skipping...
# --> 3426 event (event ID: 105153) could not survive the image cleaning. Skipping...
# --> 3447 event (event ID: 105177) could not survive the image cleaning. Skipping...
# --> 3454 event (event ID: 105186) could not survive the image cleaning. Skipping...
# --> 3456 event (event ID: 105188) could not survive the image cleaning. Skipping...
# --> 3466 event (event ID: 105204) could not survive the image cleaning. Skipping...
# --> 3468 event (event ID: 105207) could not survive the image cleaning. Skipping...
# --> 3470 event (event ID: 105209) could not survive the image cleaning. Skipping...
# --> 3478 event (event ID: 105219) could not survive the image cleaning. Skipping...
# --> 3486 event (event ID: 105236) could not survive the image cleaning. Skipping...
# 3500 events
# --> 3501 event (event ID: 105262) could not survive the image cleaning. Skipping...
# --> 3502 event (event ID: 105264) could not survive the image cleaning. Skipping...
# --> 3503 event (event ID: 105266) could not survive the image cleaning. Skipping...
# --> 3505 event (event ID: 105269) could not survive the image cleaning. Skipping...
# --> 3506 event (event ID: 105270) could not survive the image cleaning. Skipping...
# --> 3509 event (event ID: 105274) could not survive the image cleaning. Skipping...
# --> 3511 event (event ID: 105277) could not survive the image cleaning. Skipping...
# --> 3521 event (event ID: 105290) could not survive the image cleaning. Skipping...
# --> 3522 event (event ID: 105292) could not survive the image cleaning. Skipping...
# --> 3528 event (event ID: 105301) could not survive the image cleaning. Skipping...
# --> 3529 event (event ID: 105302) could not survive the image cleaning. Skipping...
# --> 3530 event (event ID: 105303) could not survive the image cleaning. Skipping...
# --> 3532 event (event ID: 105305) could not survive the image cleaning. Skipping...
# --> 3533 event (event ID: 105306) could not survive the image cleaning. Skipping...
# --> 3536 event (event ID: 105310) could not survive the image cleaning. Skipping...
# --> 3538 event (event ID: 105313) could not survive the image cleaning. Skipping...
# --> 3540 event (event ID: 105315) could not survive the image cleaning. Skipping...
# --> 3541 event (event ID: 105316) could not survive the image cleaning. Skipping...
# --> 3546 event (event ID: 105321) could not survive the image cleaning. Skipping...
# --> 3550 event (event ID: 105326) could not survive the image cleaning. Skipping...
# --> 3556 event (event ID: 105336) could not survive the image cleaning. Skipping...
# --> 3558 event (event ID: 105341) could not survive the image cleaning. Skipping...
# --> 3560 event (event ID: 105343) could not survive the image cleaning. Skipping...
# --> 3561 event (event ID: 105344) could not survive the image cleaning. Skipping...
# --> 3565 event (event ID: 105348) could not survive the image cleaning. Skipping...
# --> 3568 event (event ID: 105352) could not survive the image cleaning. Skipping...
# --> 3571 event (event ID: 105355) could not survive the image cleaning. Skipping...
# --> 3574 event (event ID: 105362) could not survive the image cleaning. Skipping...
# --> 3577 event (event ID: 105365) could not survive the image cleaning. Skipping...
# --> 3584 event (event ID: 105373) could not survive the image cleaning. Skipping...
# --> 3587 event (event ID: 105377) could not survive the image cleaning. Skipping...
# --> 3590 event (event ID: 105380) could not survive the image cleaning. Skipping...
# --> 3598 event (event ID: 105389) could not survive the image cleaning. Skipping...
# 3600 events
# --> 3603 event (event ID: 105398) could not survive the image cleaning. Skipping...
# --> 3606 event (event ID: 105402) could not survive the image cleaning. Skipping...
# --> 3610 event (event ID: 105406) could not survive the image cleaning. Skipping...
# --> 3611 event (event ID: 105408) could not survive the image cleaning. Skipping...
# --> 3612 event (event ID: 105409) could not survive the image cleaning. Skipping...
# --> 3623 event (event ID: 105427) could not survive the image cleaning. Skipping...
# --> 3627 event (event ID: 105432) could not survive the image cleaning. Skipping...
# --> 3628 event (event ID: 105433) could not survive the image cleaning. Skipping...
# --> 3633 event (event ID: 105440) could not survive the image cleaning. Skipping...
# --> 3635 event (event ID: 105442) could not survive the image cleaning. Skipping...
# --> 3638 event (event ID: 105448) could not survive the image cleaning. Skipping...
# --> 3641 event (event ID: 105451) could not survive the image cleaning. Skipping...
# --> 3642 event (event ID: 105452) could not survive the image cleaning. Skipping...
# --> 3643 event (event ID: 105453) could not survive the image cleaning. Skipping...
# --> 3649 event (event ID: 105460) could not survive the image cleaning. Skipping...
# --> 3651 event (event ID: 105462) could not survive the image cleaning. Skipping...
# --> 3655 event (event ID: 105466) could not survive the image cleaning. Skipping...
# --> 3658 event (event ID: 105470) could not survive the image cleaning. Skipping...
# --> 3661 event (event ID: 105474) could not survive the image cleaning. Skipping...
# --> 3662 event (event ID: 105475) could not survive the image cleaning. Skipping...
# --> 3664 event (event ID: 105477) could not survive the image cleaning. Skipping...
# --> 3671 event (event ID: 105484) could not survive the image cleaning. Skipping...
# --> 3684 event (event ID: 105499) could not survive the image cleaning. Skipping...
# --> 3686 event (event ID: 105501) could not survive the image cleaning. Skipping...
# --> 3695 event (event ID: 105511) could not survive the image cleaning. Skipping...
# --> 3699 event (event ID: 105516) could not survive the image cleaning. Skipping...
# 3700 events
# --> 3702 event (event ID: 105519) could not survive the image cleaning. Skipping...
# --> 3705 event (event ID: 105522) could not survive the image cleaning. Skipping...
# --> 3707 event (event ID: 105525) could not survive the image cleaning. Skipping...
# --> 3710 event (event ID: 105528) could not survive the image cleaning. Skipping...
# --> 3720 event (event ID: 105538) could not survive the image cleaning. Skipping...
# --> 3724 event (event ID: 105543) could not survive the image cleaning. Skipping...
# --> 3729 event (event ID: 105549) could not survive the image cleaning. Skipping...
# --> 3730 event (event ID: 105550) could not survive the image cleaning. Skipping...
# --> 3731 event (event ID: 105552) could not survive the image cleaning. Skipping...
# --> 3737 event (event ID: 105564) could not survive the image cleaning. Skipping...
# --> 3743 event (event ID: 105570) could not survive the image cleaning. Skipping...
# --> 3744 event (event ID: 105573) could not survive the image cleaning. Skipping...
# --> 3748 event (event ID: 105577) could not survive the image cleaning. Skipping...
# --> 3752 event (event ID: 105582) could not survive the image cleaning. Skipping...
# --> 3753 event (event ID: 105583) could not survive the image cleaning. Skipping...
# ...
# --> 25072 event (event ID: 128654) could not survive the image cleaning. Skipping...
# --> 25076 event (event ID: 128658) could not survive the image cleaning. Skipping...
# --> 25078 event (event ID: 128660) could not survive the image cleaning. Skipping...
# --> 25096 event (event ID: 128679) failed to extract finite timing parameters. Skipping...
# 25100 events
# --> 25103 event (event ID: 128687) could not survive the image cleaning. Skipping...
# --> 25107 event (event ID: 128692) could not survive the image cleaning. Skipping...
# --> 25109 event (event ID: 128694) could not survive the image cleaning. Skipping...
# --> 25123 event (event ID: 128710) could not survive the image cleaning. Skipping...
# --> 25124 event (event ID: 128711) could not survive the image cleaning. Skipping...
# --> 25143 event (event ID: 128731) could not survive the image cleaning. Skipping...
# --> 25148 event (event ID: 128736) could not survive the image cleaning. Skipping...
# --> 25162 event (event ID: 128750) could not survive the image cleaning. Skipping...
# --> 25179 event (event ID: 128768) could not survive the image cleaning. Skipping...
# --> 25182 event (event ID: 128771) could not survive the image cleaning. Skipping...
# --> 25192 event (event ID: 128782) could not survive the image cleaning. Skipping...
# 25200 events
# --> 25202 event (event ID: 128793) could not survive the image cleaning. Skipping...
# --> 25209 event (event ID: 128801) could not survive the image cleaning. Skipping...
# --> 25212 event (event ID: 128804) could not survive the image cleaning. Skipping...
# --> 25230 event (event ID: 128823) could not survive the image cleaning. Skipping...
# --> 25234 event (event ID: 128827) could not survive the image cleaning. Skipping...
# --> 25235 event (event ID: 128828) could not survive the image cleaning. Skipping...
# --> 25254 event (event ID: 128848) could not survive the image cleaning. Skipping...
# --> 25259 event (event ID: 128853) could not survive the image cleaning. Skipping...
# --> 25264 event (event ID: 128859) could not survive the image cleaning. Skipping...
# --> 25279 event (event ID: 128874) could not survive the image cleaning. Skipping...
# --> 25296 event (event ID: 128891) could not survive the image cleaning. Skipping...
# --> 25297 event (event ID: 128892) could not survive the image cleaning. Skipping...
# --> 25298 event (event ID: 128893) could not survive the image cleaning. Skipping...
# 25300 events
# --> 25303 event (event ID: 128898) could not survive the image cleaning. Skipping...
# --> 25307 event (event ID: 128902) could not survive the image cleaning. Skipping...
# --> 25323 event (event ID: 128920) could not survive the image cleaning. Skipping...
# --> 25338 event (event ID: 128935) could not survive the image cleaning. Skipping...
# --> 25344 event (event ID: 128941) could not survive the image cleaning. Skipping...
# --> 25346 event (event ID: 128943) could not survive the image cleaning. Skipping...
# --> 25358 event (event ID: 128956) could not survive the image cleaning. Skipping...
# --> 25363 event (event ID: 128961) failed to extract finite timing parameters. Skipping...
# --> 25364 event (event ID: 128962) could not survive the image cleaning. Skipping...
# --> 25381 event (event ID: 128979) could not survive the image cleaning. Skipping...
# --> 25385 event (event ID: 128984) could not survive the image cleaning. Skipping...
# --> 25388 event (event ID: 128987) could not survive the image cleaning. Skipping...
# 25400 events
# --> 25402 event (event ID: 129001) could not survive the image cleaning. Skipping...
# --> 25415 event (event ID: 129014) could not survive the image cleaning. Skipping...
# --> 25439 event (event ID: 129041) could not survive the image cleaning. Skipping...
# --> 25445 event (event ID: 129047) could not survive the image cleaning. Skipping...
# --> 25446 event (event ID: 129049) could not survive the image cleaning. Skipping...
# --> 25450 event (event ID: 129053) could not survive the image cleaning. Skipping...
# --> 25451 event (event ID: 129054) could not survive the image cleaning. Skipping...
# --> 25457 event (event ID: 129060) could not survive the image cleaning. Skipping...
# --> 25459 event (event ID: 129062) could not survive the image cleaning. Skipping...
# --> 25471 event (event ID: 129074) could not survive the image cleaning. Skipping...
# --> 25474 event (event ID: 129077) could not survive the image cleaning. Skipping...
# --> 25477 event (event ID: 129080) could not survive the image cleaning. Skipping...
# --> 25488 event (event ID: 129091) could not survive the image cleaning. Skipping...
# --> 25489 event (event ID: 129092) could not survive the image cleaning. Skipping...
# --> 25493 event (event ID: 129096) could not survive the image cleaning. Skipping...
# 25500 events
# --> 25503 event (event ID: 129107) could not survive the image cleaning. Skipping...
# --> 25507 event (event ID: 129111) could not survive the image cleaning. Skipping...
# --> 25514 event (event ID: 129118) could not survive the image cleaning. Skipping...
# --> 25516 event (event ID: 129120) could not survive the image cleaning. Skipping...
# --> 25517 event (event ID: 129121) could not survive the image cleaning. Skipping...
# --> 25523 event (event ID: 129128) could not survive the image cleaning. Skipping...
# --> 25526 event (event ID: 129131) could not survive the image cleaning. Skipping...
# --> 25536 event (event ID: 129142) could not survive the image cleaning. Skipping...
# --> 25547 event (event ID: 129154) could not survive the image cleaning. Skipping...
# --> 25554 event (event ID: 129162) could not survive the image cleaning. Skipping...
# --> 25555 event (event ID: 129163) could not survive the image cleaning. Skipping...
# --> 25558 event (event ID: 129166) could not survive the image cleaning. Skipping...
# --> 25567 event (event ID: 129176) could not survive the image cleaning. Skipping...
# --> 25582 event (event ID: 129191) could not survive the image cleaning. Skipping...
# --> 25585 event (event ID: 129194) could not survive the image cleaning. Skipping...
# 25600 events
# --> 25604 event (event ID: 129216) could not survive the image cleaning. Skipping...
# --> 25606 event (event ID: 129218) could not survive the image cleaning. Skipping...
# --> 25608 event (event ID: 129220) could not survive the image cleaning. Skipping...
# --> 25631 event (event ID: 129244) could not survive the image cleaning. Skipping...
# --> 25635 event (event ID: 129248) could not survive the image cleaning. Skipping...
# --> 25655 event (event ID: 129269) could not survive the image cleaning. Skipping...
# --> 25661 event (event ID: 129276) could not survive the image cleaning. Skipping...
# --> 25666 event (event ID: 129281) could not survive the image cleaning. Skipping...
# --> 25669 event (event ID: 129284) could not survive the image cleaning. Skipping...
# --> 25679 event (event ID: 129294) could not survive the image cleaning. Skipping...
# --> 25688 event (event ID: 129303) could not survive the image cleaning. Skipping...
# --> 25689 event (event ID: 129305) could not survive the image cleaning. Skipping...
# 25700 events
# --> 25702 event (event ID: 129318) could not survive the image cleaning. Skipping...
# --> 25710 event (event ID: 129326) could not survive the image cleaning. Skipping...
# --> 25742 event (event ID: 129361) failed to extract finite timing parameters. Skipping...
# --> 25744 event (event ID: 129363) could not survive the image cleaning. Skipping...
# --> 25748 event (event ID: 129367) could not survive the image cleaning. Skipping...
# --> 25755 event (event ID: 129374) could not survive the image cleaning. Skipping...
# --> 25767 event (event ID: 129387) could not survive the image cleaning. Skipping...
# --> 25791 event (event ID: 129413) could not survive the image cleaning. Skipping...
# --> 25793 event (event ID: 129415) could not survive the image cleaning. Skipping...
# 25800 events
# --> 25813 event (event ID: 129435) could not survive the image cleaning. Skipping...
# --> 25816 event (event ID: 129438) could not survive the image cleaning. Skipping...
# --> 25818 event (event ID: 129440) could not survive the image cleaning. Skipping...
# --> 25846 event (event ID: 129471) could not survive the image cleaning. Skipping...
# --> 25874 event (event ID: 129500) could not survive the image cleaning. Skipping...
# --> 25876 event (event ID: 129502) could not survive the image cleaning. Skipping...
# --> 25881 event (event ID: 129507) could not survive the image cleaning. Skipping...
# --> 25899 event (event ID: 129526) could not survive the image cleaning. Skipping...
# 25900 events
# --> 25904 event (event ID: 129531) could not survive the image cleaning. Skipping...
# --> 25907 event (event ID: 129534) failed to extract finite timing parameters. Skipping...
# --> 25921 event (event ID: 129548) could not survive the image cleaning. Skipping...
# --> 25927 event (event ID: 129554) could not survive the image cleaning. Skipping...
# --> 25929 event (event ID: 129556) could not survive the image cleaning. Skipping...
# --> 25933 event (event ID: 129560) could not survive the image cleaning. Skipping...
# --> 25935 event (event ID: 129562) could not survive the image cleaning. Skipping...
# --> 25943 event (event ID: 129571) failed to extract finite timing parameters. Skipping...
# --> 25952 event (event ID: 129580) could not survive the image cleaning. Skipping...
# --> 25980 event (event ID: 129610) could not survive the image cleaning. Skipping...
# --> 25981 event (event ID: 129611) could not survive the image cleaning. Skipping...
# --> 25990 event (event ID: 129620) could not survive the image cleaning. Skipping...
# 26000 events
# --> 26014 event (event ID: 129646) could not survive the image cleaning. Skipping...
# --> 26015 event (event ID: 129647) could not survive the image cleaning. Skipping...
# --> 26030 event (event ID: 129662) could not survive the image cleaning. Skipping...
# --> 26040 event (event ID: 129674) could not survive the image cleaning. Skipping...
# --> 26044 event (event ID: 129678) could not survive the image cleaning. Skipping...
# --> 26051 event (event ID: 129685) could not survive the image cleaning. Skipping...
# --> 26060 event (event ID: 129694) could not survive the image cleaning. Skipping...
# --> 26067 event (event ID: 129701) could not survive the image cleaning. Skipping...
# --> 26082 event (event ID: 129716) could not survive the image cleaning. Skipping...
# --> 26086 event (event ID: 129720) could not survive the image cleaning. Skipping...
# --> 26097 event (event ID: 129732) could not survive the image cleaning. Skipping...
# 26100 events
# --> 26119 event (event ID: 129756) could not survive the image cleaning. Skipping...
# --> 26120 event (event ID: 129757) could not survive the image cleaning. Skipping...
# --> 26125 event (event ID: 129763) could not survive the image cleaning. Skipping...
# --> 26131 event (event ID: 129769) could not survive the image cleaning. Skipping...
# --> 26138 event (event ID: 129777) could not survive the image cleaning. Skipping...
# --> 26143 event (event ID: 129782) could not survive the image cleaning. Skipping...
# --> 26161 event (event ID: 129802) could not survive the image cleaning. Skipping...
# --> 26164 event (event ID: 129806) could not survive the image cleaning. Skipping...
# --> 26166 event (event ID: 129808) could not survive the image cleaning. Skipping...
# --> 26169 event (event ID: 129811) could not survive the image cleaning. Skipping...
# --> 26174 event (event ID: 129816) could not survive the image cleaning. Skipping...
# --> 26191 event (event ID: 129833) could not survive the image cleaning. Skipping...
# --> 26198 event (event ID: 129841) could not survive the image cleaning. Skipping...
# 26200 events
# --> 26209 event (event ID: 129854) could not survive the image cleaning. Skipping...
# --> 26227 event (event ID: 129872) could not survive the image cleaning. Skipping...
# --> 26228 event (event ID: 129874) could not survive the image cleaning. Skipping...
# --> 26231 event (event ID: 129877) could not survive the image cleaning. Skipping...
# --> 26237 event (event ID: 129883) could not survive the image cleaning. Skipping...
# --> 26252 event (event ID: 129898) could not survive the image cleaning. Skipping...
# --> 26253 event (event ID: 129900) could not survive the image cleaning. Skipping...
# --> 26260 event (event ID: 129911) could not survive the image cleaning. Skipping...
# --> 26261 event (event ID: 129912) could not survive the image cleaning. Skipping...
# --> 26264 event (event ID: 129915) could not survive the image cleaning. Skipping...
# --> 26271 event (event ID: 129922) could not survive the image cleaning. Skipping...
# --> 26288 event (event ID: 129940) could not survive the image cleaning. Skipping...
# --> 26293 event (event ID: 129945) could not survive the image cleaning. Skipping...
# --> 26296 event (event ID: 129949) could not survive the image cleaning. Skipping...
# --> 26299 event (event ID: 129952) could not survive the image cleaning. Skipping...
# 26300 events
# --> 26312 event (event ID: 129966) could not survive the image cleaning. Skipping...
# --> 26315 event (event ID: 129969) could not survive the image cleaning. Skipping...
# --> 26320 event (event ID: 129977) could not survive the image cleaning. Skipping...
# --> 26329 event (event ID: 129988) could not survive the image cleaning. Skipping...
# --> 26332 event (event ID: 129991) could not survive the image cleaning. Skipping...
# --> 26334 event (event ID: 129993) could not survive the image cleaning. Skipping...
# --> 26343 event (event ID: 130005) failed to extract finite timing parameters. Skipping...
# --> 26345 event (event ID: 130007) could not survive the image cleaning. Skipping...
# --> 26348 event (event ID: 130010) could not survive the image cleaning. Skipping...
# --> 26361 event (event ID: 130025) could not survive the image cleaning. Skipping...
# --> 26366 event (event ID: 130030) could not survive the image cleaning. Skipping...
# --> 26375 event (event ID: 130039) could not survive the image cleaning. Skipping...
# --> 26392 event (event ID: 130058) could not survive the image cleaning. Skipping...
# 26400 events
# --> 26400 event (event ID: 130066) could not survive the image cleaning. Skipping...
# --> 26415 event (event ID: 130082) could not survive the image cleaning. Skipping...
# --> 26430 event (event ID: 130097) could not survive the image cleaning. Skipping...
# --> 26432 event (event ID: 130100) could not survive the image cleaning. Skipping...
# --> 26437 event (event ID: 130106) could not survive the image cleaning. Skipping...
# --> 26438 event (event ID: 130107) failed to extract finite timing parameters. Skipping...
# --> 26446 event (event ID: 130117) could not survive the image cleaning. Skipping...
# --> 26457 event (event ID: 130128) could not survive the image cleaning. Skipping...
# --> 26462 event (event ID: 130133) could not survive the image cleaning. Skipping...
# --> 26465 event (event ID: 130136) could not survive the image cleaning. Skipping...
# --> 26472 event (event ID: 130144) could not survive the image cleaning. Skipping...
# --> 26494 event (event ID: 130167) could not survive the image cleaning. Skipping...
# 26500 events
# --> 26506 event (event ID: 130180) could not survive the image cleaning. Skipping...
# --> 26509 event (event ID: 130184) could not survive the image cleaning. Skipping...
# --> 26539 event (event ID: 130215) could not survive the image cleaning. Skipping...
# --> 26541 event (event ID: 130218) could not survive the image cleaning. Skipping...
# --> 26543 event (event ID: 130221) could not survive the image cleaning. Skipping...
# --> 26544 event (event ID: 130222) failed to extract finite timing parameters. Skipping...
# --> 26549 event (event ID: 130227) could not survive the image cleaning. Skipping...
# --> 26552 event (event ID: 130230) could not survive the image cleaning. Skipping...
#
# In total 26562 events are processed.
#
# Output file: ./output/dl0_to_dl1/dl1_M2.Run05094483.h5
#
# Done.
#
# Process time: 146 [sec]

# %% [markdown]
# We will end up with two HDF5 files, one for M1 and one for M2. They contain the Hillas parameters for each event. If there are events where only M1 or M2 survives, they are stored anyway, since they might have triggered LST-1, so that one can still do a stereoscopic analysis with those events.

# %%
# if you do not want to wait for the two processes above to finish,
# there are output files already available in IT container or PIC
# just uncomment one of the two lines below.
# if you work locally, the 'output' directory is available in the
# directory of the dataset for this exercises
out_magic_to_dl1 = "/fefs/aswg/workspace/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/output/dl0_to_dl1" # IT container
#out_magic_to_dl1 = "/pnfs/pic.es/data/magic/Users/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/output/dl0_to_dl1" PIC
# !ls $out_magic_to_dl1
# Out:
# dl1_M1.Run05094483.h5  dl1_M2.Run05094483.h5

# %%
import pandas as pd
# Out:
# /tmp/ipykernel_17138/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_magic = pd.read_hdf(f"{out_magic_to_dl1}/dl1_M1.Run05094483.h5", key="events/parameters")

# %%
df_magic.head()
# Out:
#     obs_id  event_id  tel_id  pointing_alt  pointing_az  n_pixels  n_islands  \
# 0  5094483    101647       2      1.356704     4.153216        13          1
# 1  5094483    101648       2      1.356704     4.153218         6          1
# 2  5094483    101650       2      1.356703     4.153221        58          3
# 3  5094483    101651       2      1.356703     4.153222        15          1
# 4  5094483    101653       2      1.356702     4.153225       179          2
#
#    tels_with_trigger    time_sec  time_nanosec  ...     width  \
# 0                 12  1613253246     863719400  ...  0.021325
# 1                 12  1613253246     874704200  ...  0.012891
# 2                 12  1613253246     889958000  ...  0.065763
# 3                 12  1613253246     894446800  ...  0.020027
# 4                 12  1613253246     906102000  ...  0.136851
#
#    width_uncertainty        psi  intercept  deviation     slope  \
# 0           0.001318 -77.698046  14.893902   0.390143 -0.785664
# 1           0.001283 -11.234004  14.318125   0.425586 -5.983845
# 2           0.001618  20.960750  16.584101   0.520959 -3.981428
# 3           0.001505 -27.275508  14.072912   0.471732 -5.708893
# 4           0.001583  -9.291565  14.180575   1.246654 -1.008961
#
#    pixels_width_1  pixels_width_2  intensity_width_1  intensity_width_2
# 0        0.000000        0.000000           0.000000           0.000000
# 1        0.000000        0.000000           0.000000           0.000000
# 2        0.004812        0.009625           0.096326           0.188398
# 3        0.000000        0.000000           0.000000           0.000000
# 4        0.011550        0.023099           0.058360           0.129374
#
# [5 rows x 30 columns]

# %% [markdown]
# Note that `tel_id` is equal to 2 for M1, as configured in the configuration file. All the other parameters comes from the computation of the Hillas and timing parameters.
#
# `tels_with_trigger` is used only for hardware stereo trigger data (for the moment partially supported in MCP).

# %% [markdown]
# **NB: the format of the DL1b files generated by `magic_calib_to_dl1` does not follow (for the moment, hopefully will change in the future) the `ctapipe` DL1 format (see https://ctapipe.readthedocs.io/en/latest/user-guide/data_models/dl1.html#dl1-data-model), so you cannot use e.g. the `HDF5EventSource` to read the HDF5 files produced by `magic_calib_to_dl1` (or the `ctapipe` `process` tool).**

# %% [markdown]
# ### Full analysis scenario
#
# When performing the full analysis, what you would do is to take the first subrun file for each run and each telescope (e.g. `20210214_M1_05094483.001_Y_CrabNebula-W0.40+215.root` and `20210214_M2_05094483.001_Y_CrabNebula-W0.40+215.root` for our example) and run `magic_calib_to_dl1` over them, using the `--process-run` option. Therefore, if you have e.g. 8 runs, you will end up with 16 files (8 for M1 and 8 for M2).

# %% [markdown]
# ## Coincidence between MAGIC and LST-1 events
#
# Now that we have MAGIC DL1b files, LST-1 enters the game. For the data we are considering, the data were taken with no hardware stereo trigger between MAGIC and LST-1. So, while the telescopes were pointing the same position in the sky, there was no common trigger between the two systems, which took data independently.
#
# For such reason, we can perform only a software trigger, by looking at the timestamps of the events as recorded by MAGIC and LST-1, and looking for coincident events.
#
# To perform the coincidence, one has to take into account that there is a time offset between the events recorded by MAGIC and LST-1 due to the different light path that photons travel to reach the telescopes (plus, a constant offset due to cable lenghts).

# %% [markdown]
# Here the important part of the configuration file is:
#
# ```
# event_coincidence:
#     # History of the time offset between LST-1 and MAGIC
#     # before June 12 2021: -3.1 us
#     # June 13 2021 to Feb 28 2023: -6.5 us
#     # March 10 2023 to March 30 2023: -76039.3 us
#     # April 13 2023 to August 2023: -25.1 us
#     # after Sep 11 2023 : -6.2 us
#     timestamp_type_lst: "dragon_time"  # select "dragon_time", "tib_time" or "ucts_time"
#     window_half_width: "300 ns"
#     pre_offset_search: false
#     n_pre_offset_search_events: 100
#     time_offset:
#         start: "-10 us"
#         stop: "0 us"
# ```
#
# You can see that the offset is not always the same in different periods. Thanks to Seiya (いいね！), there is a time offset history available in the configuration file to help analyzers (to be updated). However, it can happen that in some days the offset is not the one noted above (this is because the LST-1 timing was shifted more).
#
# The event coincidence can be performed in two ways.
#
# ### Standard coincidence search
#
# By specifying `pre_offset_search : false` and values for `start` and `stop` for `time_offset`. In that case, the script will scan the number of coincidences between MAGIC and LST-1 as a function of the time offset (from `start` to `stop` in steps of 0.1 us) in a time window defined by `2*window_half_width`. Then the time offset value giving the highest number of coincidences is found (or the mean of the time offsets giving the same highest number of coincidences), let's call it $t_\text{offset,max}$. The final value of the time offset is computed as the weithed average of the time offsets within `4*window_half_width` (i.e. twice the time window) centered on $t_\text{offset,max}$. The weights are the number of coincidences on those time offsets.
#
# <img src="files/coincidence_no_preoffset.png">
#
# As you can guess, this first method assumes that the offset is somewhat known with good precision. If that is not the case, the so-called pre-offset search introduced by Seiya (いいね！) can be used:
#
# ### Pre-offset coincidence search
#
# Set `pre_offset_search : true` to use this method.
#
# - extract N (specified by `n_pre_offset_search_events`, default is 100) largest MAGIC/LST events
# - compute all possible time combinations (N x N) between extracted MAGIC/LST events
# - search the best time offset by counting the number of coincident events using N x N events with an assumption of one of the offset combinations
# - when the best time offset is found by the pre-offset search, the final time offset is found from the scan as in the standard coincidence search
#
# Here, use `window_half_width` to tell the script the range over which it will search for coincident events. This is useful when one does not know the time offset. Still, one needs to have an idea of the time offset (even if not precisely). For example, if there is a time offset of seconds, the default window half width is not enough.

# %% [markdown]
# ### Coincidence hands-on
#
# For this hands-on, I will use the standard search and also the pre-offset, so that one can see how they work.

# %%
lst1_input_file = "/home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/input/LST/dl1_LST-1.Run03631.0000.h5"
#lst1_input_file = "/fefs/aswg/workspace/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/input/LST/dl1_LST-1.Run03631.0000.h5" IT container
#lst1_input_file = "/pnfs/pic.es/data/magic/Users/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/input/LST/dl1_LST-1.Run03631.0000.h5" PIC

# %%
out_coincidence = "./output/coincidence"
# !mkdir -p $out_coincidence

# %%
config_file_preoffset = "/home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/conf/config_preoffset.yaml"
#config_file_preoffset = "/fefs/aswg/workspace/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/conf/config_preoffset.yaml" IT container
#config_file_preoffset = "/pnfs/pic.es/data/magic/Users/analysis-school-2024/MCP/dl0_dl1_coincidence_stereo/conf/config_preoffset.yaml" PIC
! cat $config_file_preoffset
# Out:
# mc_tel_ids:
#     LST-1: 1
#     LST-2: 0
#     LST-3: 0
#     LST-4: 0
#     MAGIC-I: 2
#     MAGIC-II: 3
#
#
# LST:
#     image_extractor:
#         type: "LocalPeakWindowSum"
#         window_shift: 4
#         window_width: 8
#
#     increase_nsb:
#         use: true
#         extra_noise_in_dim_pixels: 1.27
#         extra_bias_in_dim_pixels: 0.665
#         transition_charge: 8
#         extra_noise_in_bright_pixels: 2.08
#
#     increase_psf:
#         use: false
#         fraction: null
#
#     tailcuts_clean:
#         picture_thresh: 8
#         boundary_thresh: 4
#         keep_isolated_pixels: false
#         min_number_picture_neighbors: 2
#
#     time_delta_cleaning:
#         use: true
#         min_number_neighbors: 1
#         time_limit: 2
#
#     dynamic_cleaning:
#         use: true
#         threshold: 267
#         fraction: 0.03
#
#     use_only_main_island: false
#
#
# MAGIC:
#     image_extractor:
#         type: "SlidingWindowMaxSum"
#         window_width: 5
#         apply_integration_correction: false
#
#     charge_correction:
#         use: true
#         factor: 1.143
#
#     magic_clean:
#         use_time: true
#         use_sum: true
#         picture_thresh: 6
#         boundary_thresh: 3.5
#         max_time_off: 4.5
#         max_time_diff: 1.5
#         find_hotpixels: true
#         pedestal_type: "from_extractor_rndm"
#
#     muon_ring:
#         thr_low: 25
#         tailcut: [12, 8]
#         ring_completeness_threshold: 25
#
#
# event_coincidence:
#     # History of the time offset between LST-1 and MAGIC
#     # before June 12 2021: -3.1 us
#     # June 13 2021 to Feb 28 2023: -6.5 us
#     # March 10 2023 to March 30 2023: -76039.3 us
#     # April 13 2023 to August 2023: -25.1 us
#     # after Sep 11 2023 : -6.2 us
#     timestamp_type_lst: "dragon_time"  # select "dragon_time", "tib_time" or "ucts_time"
#     window_half_width: "300 ns"
#     pre_offset_search: true
#     n_pre_offset_search_events: 100
#     time_offset:
#         start: "-10 us"
#         stop: "0 us"
#
#
# stereo_reco:
#     quality_cuts: "(intensity > 50) & (width > 0)"
#     theta_uplim: "6 arcmin"
#
#
# energy_regressor:
#     settings:
#         n_estimators: 150
#         criterion: "squared_error"
#         max_depth: 50
#         min_samples_split: 2
#         min_samples_leaf: 2
#         min_weight_fraction_leaf: 0.0
#         max_features: 1.0
#         max_leaf_nodes: null
#         min_impurity_decrease: 0.0
#         bootstrap: true
#         oob_score: false
#         n_jobs: 5
#         random_state: 42
#         verbose: 0
#         warm_start: false
#         ccp_alpha: 0.0
#         max_samples: null
#
#     features: [
#         "intensity",
#         "length",
#         "width",
#         "skewness",
#         "kurtosis",
#         "slope",
#         "intensity_width_2",
#         "h_max",
#         "impact",
#         "pointing_alt",
#         "pointing_az",
#     ]
#
#     gamma_offaxis:
#         min: null
#         max: null
#
#
# disp_regressor:
#     settings:
#         n_estimators: 150
#         criterion: "squared_error"
#         max_depth: 50
#         min_samples_split: 2
#         min_samples_leaf: 2
#         min_weight_fraction_leaf: 0.0
#         max_features: 1.0
#         max_leaf_nodes: null
#         min_impurity_decrease: 0.0
#         bootstrap: true
#         oob_score: false
#         n_jobs: 5
#         random_state: 42
#         verbose: 0
#         warm_start: false
#         ccp_alpha: 0.0
#         max_samples: null
#
#     features: [
#         "intensity",
#         "length",
#         "width",
#         "skewness",
#         "kurtosis",
#         "slope",
#         "intensity_width_2",
#         "h_max",
#         "impact",
#         "pointing_alt",
#         "pointing_az",
#     ]
#
#     gamma_offaxis:
#         min: null
#         max: null
#
#
# event_classifier:
#     settings:
#         n_estimators: 100
#         criterion: "gini"
#         max_depth: 100
#         min_samples_split: 2
#         min_samples_leaf: 2
#         min_weight_fraction_leaf: 0.0
#         max_features: "sqrt"
#         max_leaf_nodes: null
#         min_impurity_decrease: 0.0
#         bootstrap: true
#         oob_score: false
#         n_jobs: 5
#         random_state: 42
#         verbose: 0
#         warm_start: false
#         class_weight: null
#         ccp_alpha: 0.0
#         max_samples: null
#
#     features: [
#         "intensity",
#         "length",
#         "width",
#         "skewness",
#         "kurtosis",
#         "slope",
#         "intensity_width_2",
#         "h_max",
#         "impact",
#         "pointing_alt",
#         "pointing_az",
#     ]
#
#     gamma_offaxis:
#         min: null
#         max: null
#
#
# create_irf:
#     quality_cuts: "disp_diff_mean < 0.22"
#     event_type: "magic_only"  # select "software", "software_only_3tel", "magic_only" or "hardware"
#     weight_type_dl2: "intensity"  # select "simple", "variance" or "intensity"
#     obs_time_irf: "50 h"  # used when creating a background HDU
#
#     energy_bins:  # log space
#         start: "0.01 TeV"
#         stop: "1000 TeV"
#         n_edges: 26
#
#     migration_bins:  # log space
#         start: 0.2
#         stop: 5
#         n_edges: 31
#
#     fov_offset_bins:  # linear space, used for diffuse MCs
#         start: "0 deg"
#         stop: "1 deg"
#         n_edges: 6
#
#     source_offset_bins:  # linear space, used when creating PSF HDU
#         start: "0 deg"
#         stop: "1 deg"
#         n_edges: 101
#
#     bkg_fov_offset_bins:  # linear space, used when creating background HDU
#         start: "0 deg"
#         stop: "10 deg"
#         n_edges: 21
#
#     gammaness:
#         cut_type: "dynamic"  # select "global" or "dynamic"
#         global_cut_value: 0.8  # used for the global cut
#         efficiency: 0.9  # used for the dynamic cuts
#         min_cut: 0.05  # used for the dynamic cuts
#         max_cut: 0.85  # used for the dynamic cuts
#
#     theta:
#         cut_type: "dynamic"  # select "global" or "dynamic"
#         global_cut_value: "0.2 deg"  # used for the global cut
#         efficiency: 0.75  # used for the dynamic cuts
#         min_cut: "0.1 deg"  # used for the dynamic cuts
#         max_cut: "0.25 deg"  # used for the dynamic cuts
#
#
# dl2_to_dl3:
#     interpolation_method: "linear"  # select "nearest", "linear" or "cubic"
#     interpolation_scheme: "cosZd" # select "cosZdAz" or "cosZd"
#     max_distance: "45. deg"  # angle type Quantity, or comment out to remove the cut
#     source_name: "Crab"
#     source_ra: null  # used when the source name cannot be resolved
#     source_dec: null  # used when the source name cannot be resolved

# %%
# !lst1_magic_event_coincidence -h
# Out:
# usage: lst1_magic_event_coincidence [-h] --input-file-lst INPUT_FILE_LST
#                                     --input-dir-magic INPUT_DIR_MAGIC
#                                     [--output-dir OUTPUT_DIR]
#                                     [--config-file CONFIG_FILE]
#
# options:
#   -h, --help            show this help message and exit
#   --input-file-lst INPUT_FILE_LST, -l INPUT_FILE_LST
#                         Path to an input LST DL1 data file
#   --input-dir-magic INPUT_DIR_MAGIC, -m INPUT_DIR_MAGIC
#                         Path to a directory where input MAGIC DL1 data files
#                         are stored
#   --output-dir OUTPUT_DIR, -o OUTPUT_DIR
#                         Path to a directory where to save an output DL1 data
#                         file
#   --config-file CONFIG_FILE, -c CONFIG_FILE
#                         Path to a configuration file

# %%
# !lst1_magic_event_coincidence -l $lst1_input_file -m $out_magic_to_dl1 -o $out_coincidence -c $config_file_preoffset
# Out:
# Input LST DL1 data file: /home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/input/LST/dl1_LST-1.Run03631.0000.h5
# LST-1: 32936 events
#
# Input MAGIC directory: ./output/dl0_to_dl1
#
# The following DL1 data files are found:
# ./output/dl0_to_dl1/dl1_M1.Run05094483.h5
# ./output/dl0_to_dl1/dl1_M2.Run05094483.h5
# MAGIC-I: 21787 events
# MAGIC-II: 23404 events
#
# LST timestamp type: dragon_time
#
# Coincidence window half width: 300 ns
#
# Pre offset search will be performed.
#
# Pre offset search using large-intensity shower events is ongoing...
#
# Extracting the MAGIC-I events taken when LST observed for pre offset search...
# --> 1330 events are found.
#
# Pre offset search finds -3.0 us as a possible offset
#
# Time offsets scan region:
#   start: -3.9 us
#   stop: -2.1 us
#
# Extracting the MAGIC-I events taken when LST observed...
# --> 1330 events are found.
#
# Checking the event coincidence...
# time offset: -3.9 us --> 0 events
# time offset: -3.8 us --> 0 events
# time offset: -3.7 us --> 1 events
# time offset: -3.6 us --> 8 events
# time offset: -3.5 us --> 106 events
# time offset: -3.4 us --> 296 events
# time offset: -3.3 us --> 668 events
# time offset: -3.2 us --> 792 events
# time offset: -3.1 us --> 841 events
# time offset: -3.0 us --> 846 events
# time offset: -2.9 us --> 843 events
# time offset: -2.8 us --> 746 events
# time offset: -2.7 us --> 558 events
# time offset: -2.6 us --> 190 events
# time offset: -2.5 us --> 68 events
# time offset: -2.4 us --> 19 events
# time offset: -2.3 us --> 15 events
# time offset: -2.2 us --> 12 events
#
# Average offset: -3.016 us
# --> Number of coincident events: 840
# --> Fraction over the MAGIC-I events: 63.2%
#
# Pre offset search using large-intensity shower events is ongoing...
#
# Extracting the MAGIC-II events taken when LST observed for pre offset search...
# --> 1417 events are found.
#
# Pre offset search finds -3.0 us as a possible offset
#
# Time offsets scan region:
#   start: -3.9 us
#   stop: -2.1 us
#
# Extracting the MAGIC-II events taken when LST observed...
# --> 1417 events are found.
#
# Checking the event coincidence...
# time offset: -3.9 us --> 1 events
# time offset: -3.8 us --> 1 events
# time offset: -3.7 us --> 2 events
# time offset: -3.6 us --> 39 events
# time offset: -3.5 us --> 323 events
# time offset: -3.4 us --> 597 events
# time offset: -3.3 us --> 867 events
# time offset: -3.2 us --> 904 events
# time offset: -3.1 us --> 919 events
# time offset: -3.0 us --> 924 events
# time offset: -2.9 us --> 892 events
# time offset: -2.8 us --> 610 events
# time offset: -2.7 us --> 338 events
# time offset: -2.6 us --> 69 events
# time offset: -2.5 us --> 35 events
# time offset: -2.4 us --> 20 events
# time offset: -2.3 us --> 15 events
# time offset: -2.2 us --> 12 events
#
# Average offset: -3.090 us
# --> Number of coincident events: 918
# --> Fraction over the MAGIC-II events: 64.8%
#
# In total 1379 stereo events are found:
#     LST-1_MAGIC-I (type 0): 36 events (2.6%)
#     LST-1_MAGIC-I_MAGIC-II (type 1): 832 events (60.3%)
#     LST-1_MAGIC-II (type 2): 102 events (7.4%)
#     MAGIC-I_MAGIC-II (type 3): 409 events (29.7%)
#
# Output file: ./output/coincidence/dl1_MAGIC_LST-1.Run03631.0000.h5
#
# Done.
#
# Process time: 5 [sec]

# %%
# !lst1_magic_event_coincidence -l $lst1_input_file -m $out_magic_to_dl1 -o $out_coincidence -c $config_file
# Out:
# Input LST DL1 data file: /home/mpp/Software/LST_SW_2024/MCP/dl0_dl1_coincidence_stereo/input/LST/dl1_LST-1.Run03631.0000.h5
# LST-1: 32936 events
#
# Input MAGIC directory: ./output/dl0_to_dl1
#
# The following DL1 data files are found:
# ./output/dl0_to_dl1/dl1_M1.Run05094483.h5
# ./output/dl0_to_dl1/dl1_M2.Run05094483.h5
# MAGIC-I: 21787 events
# MAGIC-II: 23404 events
#
# LST timestamp type: dragon_time
#
# Coincidence window half width: 300 ns
#
# offset scan range defined in the config file will be used.
#
# Time offsets scan region:
#   start: -10.0 us
#   stop: 0.0 us
#
# Extracting the MAGIC-I events taken when LST observed...
# --> 1330 events are found.
#
# Checking the event coincidence...
# time offset: -10.0 us --> 0 events
# time offset: -9.9 us --> 0 events
# time offset: -9.8 us --> 1 events
# time offset: -9.7 us --> 2 events
# time offset: -9.6 us --> 2 events
# time offset: -9.5 us --> 2 events
# time offset: -9.4 us --> 2 events
# time offset: -9.3 us --> 2 events
# time offset: -9.2 us --> 2 events
# time offset: -9.1 us --> 1 events
# time offset: -9.0 us --> 0 events
# time offset: -8.9 us --> 0 events
# time offset: -8.8 us --> 0 events
# time offset: -8.7 us --> 0 events
# time offset: -8.6 us --> 2 events
# time offset: -8.5 us --> 2 events
# time offset: -8.4 us --> 2 events
# time offset: -8.3 us --> 2 events
# time offset: -8.2 us --> 2 events
# time offset: -8.1 us --> 2 events
# time offset: -8.0 us --> 2 events
# time offset: -7.9 us --> 0 events
# time offset: -7.8 us --> 0 events
# time offset: -7.7 us --> 0 events
# time offset: -7.6 us --> 0 events
# time offset: -7.5 us --> 0 events
# time offset: -7.4 us --> 0 events
# time offset: -7.3 us --> 1 events
# time offset: -7.2 us --> 1 events
# time offset: -7.1 us --> 1 events
# time offset: -7.0 us --> 1 events
# time offset: -6.9 us --> 1 events
# time offset: -6.8 us --> 2 events
# time offset: -6.7 us --> 3 events
# time offset: -6.6 us --> 2 events
# time offset: -6.5 us --> 3 events
# time offset: -6.4 us --> 3 events
# time offset: -6.3 us --> 3 events
# time offset: -6.2 us --> 4 events
# time offset: -6.1 us --> 3 events
# time offset: -6.0 us --> 2 events
# time offset: -5.9 us --> 2 events
# time offset: -5.8 us --> 1 events
# time offset: -5.7 us --> 1 events
# time offset: -5.6 us --> 1 events
# time offset: -5.5 us --> 0 events
# time offset: -5.4 us --> 0 events
# time offset: -5.3 us --> 0 events
# time offset: -5.2 us --> 0 events
# time offset: -5.1 us --> 0 events
# time offset: -5.0 us --> 0 events
# time offset: -4.9 us --> 0 events
# time offset: -4.8 us --> 0 events
# time offset: -4.7 us --> 1 events
# time offset: -4.6 us --> 1 events
# time offset: -4.5 us --> 1 events
# time offset: -4.4 us --> 1 events
# time offset: -4.3 us --> 1 events
# time offset: -4.2 us --> 1 events
# time offset: -4.1 us --> 1 events
# time offset: -4.0 us --> 0 events
# time offset: -3.9 us --> 0 events
# time offset: -3.8 us --> 0 events
# time offset: -3.7 us --> 1 events
# time offset: -3.6 us --> 8 events
# time offset: -3.5 us --> 106 events
# time offset: -3.4 us --> 296 events
# time offset: -3.3 us --> 668 events
# time offset: -3.2 us --> 792 events
# time offset: -3.1 us --> 841 events
# time offset: -3.0 us --> 846 events
# time offset: -2.9 us --> 843 events
# time offset: -2.8 us --> 746 events
# time offset: -2.7 us --> 558 events
# time offset: -2.6 us --> 190 events
# time offset: -2.5 us --> 68 events
# time offset: -2.4 us --> 19 events
# time offset: -2.3 us --> 15 events
# time offset: -2.2 us --> 12 events
# time offset: -2.1 us --> 12 events
# time offset: -2.0 us --> 11 events
# time offset: -1.9 us --> 13 events
# time offset: -1.8 us --> 12 events
# time offset: -1.7 us --> 14 events
# time offset: -1.6 us --> 12 events
# time offset: -1.5 us --> 13 events
# time offset: -1.4 us --> 14 events
# time offset: -1.3 us --> 14 events
# time offset: -1.2 us --> 8 events
# time offset: -1.1 us --> 7 events
# time offset: -1.0 us --> 5 events
# time offset: -0.9 us --> 6 events
# time offset: -0.8 us --> 4 events
# time offset: -0.7 us --> 3 events
# time offset: -0.6 us --> 2 events
# time offset: -0.5 us --> 6 events
# time offset: -0.4 us --> 8 events
# time offset: -0.3 us --> 11 events
# time offset: -0.2 us --> 12 events
# time offset: -0.1 us --> 15 events
#
# Average offset: -3.016 us
# --> Number of coincident events: 840
# --> Fraction over the MAGIC-I events: 63.2%
#
# Time offsets scan region:
#   start: -10.0 us
#   stop: 0.0 us
#
# Extracting the MAGIC-II events taken when LST observed...
# --> 1417 events are found.
#
# Checking the event coincidence...
# time offset: -10.0 us --> 1 events
# time offset: -9.9 us --> 1 events
# time offset: -9.8 us --> 1 events
# time offset: -9.7 us --> 2 events
# time offset: -9.6 us --> 2 events
# time offset: -9.5 us --> 2 events
# time offset: -9.4 us --> 2 events
# time offset: -9.3 us --> 1 events
# time offset: -9.2 us --> 1 events
# time offset: -9.1 us --> 1 events
# time offset: -9.0 us --> 0 events
# time offset: -8.9 us --> 0 events
# time offset: -8.8 us --> 0 events
# time offset: -8.7 us --> 0 events
# time offset: -8.6 us --> 1 events
# time offset: -8.5 us --> 1 events
# time offset: -8.4 us --> 1 events
# time offset: -8.3 us --> 1 events
# time offset: -8.2 us --> 1 events
# time offset: -8.1 us --> 1 events
# time offset: -8.0 us --> 1 events
# time offset: -7.9 us --> 0 events
# time offset: -7.8 us --> 0 events
# time offset: -7.7 us --> 0 events
# time offset: -7.6 us --> 0 events
# time offset: -7.5 us --> 0 events
# time offset: -7.4 us --> 0 events
# time offset: -7.3 us --> 0 events
# time offset: -7.2 us --> 0 events
# time offset: -7.1 us --> 0 events
# time offset: -7.0 us --> 1 events
# time offset: -6.9 us --> 1 events
# time offset: -6.8 us --> 1 events
# time offset: -6.7 us --> 3 events
# time offset: -6.6 us --> 3 events
# time offset: -6.5 us --> 3 events
# time offset: -6.4 us --> 4 events
# time offset: -6.3 us --> 3 events
# time offset: -6.2 us --> 3 events
# time offset: -6.1 us --> 3 events
# time offset: -6.0 us --> 1 events
# time offset: -5.9 us --> 1 events
# time offset: -5.8 us --> 1 events
# time offset: -5.7 us --> 0 events
# time offset: -5.6 us --> 0 events
# time offset: -5.5 us --> 0 events
# time offset: -5.4 us --> 0 events
# time offset: -5.3 us --> 0 events
# time offset: -5.2 us --> 0 events
# time offset: -5.1 us --> 0 events
# time offset: -5.0 us --> 0 events
# time offset: -4.9 us --> 0 events
# time offset: -4.8 us --> 0 events
# time offset: -4.7 us --> 1 events
# time offset: -4.6 us --> 1 events
# time offset: -4.5 us --> 1 events
# time offset: -4.4 us --> 1 events
# time offset: -4.3 us --> 1 events
# time offset: -4.2 us --> 1 events
# time offset: -4.1 us --> 1 events
# time offset: -4.0 us --> 1 events
# time offset: -3.9 us --> 1 events
# time offset: -3.8 us --> 1 events
# time offset: -3.7 us --> 2 events
# time offset: -3.6 us --> 39 events
# time offset: -3.5 us --> 323 events
# time offset: -3.4 us --> 597 events
# time offset: -3.3 us --> 867 events
# time offset: -3.2 us --> 904 events
# time offset: -3.1 us --> 919 events
# time offset: -3.0 us --> 924 events
# time offset: -2.9 us --> 892 events
# time offset: -2.8 us --> 610 events
# time offset: -2.7 us --> 338 events
# time offset: -2.6 us --> 69 events
# time offset: -2.5 us --> 35 events
# time offset: -2.4 us --> 20 events
# time offset: -2.3 us --> 15 events
# time offset: -2.2 us --> 12 events
# time offset: -2.1 us --> 11 events
# time offset: -2.0 us --> 10 events
# time offset: -1.9 us --> 11 events
# time offset: -1.8 us --> 8 events
# time offset: -1.7 us --> 9 events
# time offset: -1.6 us --> 9 events
# time offset: -1.5 us --> 8 events
# time offset: -1.4 us --> 8 events
# time offset: -1.3 us --> 7 events
# time offset: -1.2 us --> 4 events
# time offset: -1.1 us --> 4 events
# time offset: -1.0 us --> 3 events
# time offset: -0.9 us --> 3 events
# time offset: -0.8 us --> 2 events
# time offset: -0.7 us --> 2 events
# time offset: -0.6 us --> 3 events
# time offset: -0.5 us --> 7 events
# time offset: -0.4 us --> 8 events
# time offset: -0.3 us --> 10 events
# time offset: -0.2 us --> 9 events
# time offset: -0.1 us --> 12 events
#
# Average offset: -3.090 us
# --> Number of coincident events: 918
# --> Fraction over the MAGIC-II events: 64.8%
#
# In total 1379 stereo events are found:
#     LST-1_MAGIC-I (type 0): 36 events (2.6%)
#     LST-1_MAGIC-I_MAGIC-II (type 1): 832 events (60.3%)
#     LST-1_MAGIC-II (type 2): 102 events (7.4%)
#     MAGIC-I_MAGIC-II (type 3): 409 events (29.7%)
#
# Output file: ./output/coincidence/dl1_MAGIC_LST-1.Run03631.0000.h5
#
# Done.
#
# Process time: 19 [sec]

# %% [markdown]
# One can see that the two approaches give the same result, great! :D

# %% [markdown]
# As you can see from the output, the script will tell you how many events there are for each "event type" i.e. each two telescope combinations and all three telescopes. Therefore, the resulting HDF5 file is a table with the events DL1b information (either MAGIC only, or MAGIC+LST-1).

# %%
df = pd.read_hdf(f"{out_coincidence}/dl1_MAGIC_LST-1.Run03631.0000.h5", key="events/parameters")
df.head()
# Out:
#    obs_id  event_id  tel_id  obs_id_magic  event_id_magic  obs_id_lst  \
# 0    3631        16       1       5094483          102313      3631.0
# 1    3631        16       3       5094483          102313      3631.0
# 2    3631        24       1       5094483          102314      3631.0
# 3    3631        24       2       5094483          102314      3631.0
# 4    3631        24       3       5094483          102314      3631.0
#
#    event_id_lst    intensity         x         y  ...  pixels_width_1  \
# 0          16.0   304.667151  0.057675 -0.414797  ...        0.000000
# 1          16.0    64.476562  0.004862 -0.107461  ...        0.000000
# 2          24.0  1155.765821  0.401519  0.354602  ...        0.000000
# 3          24.0    63.041406 -0.027460  0.304506  ...        0.000000
# 4          24.0   613.492188  0.120570  0.322906  ...        0.005775
#
#    pixels_width_2  n_pixels  n_islands  pointing_alt  pointing_az  \
# 0        0.000000        14          2      1.356512     4.153884
# 1        0.000000         7          1      1.356456     4.153876
# 2        0.000000        75          1      1.356512     4.153885
# 3        0.000000         9          1      1.356521     4.153870
# 4        0.014437        71          2      1.356456     4.153876
#
#       timestamp  time_diff  multiplicity  combo_type
# 0  1.613253e+09   0.000120             2           2
# 1  1.613253e+09   0.000923             2           2
# 2  1.613253e+09   0.000308             3           1
# 3  1.613253e+09   0.006442             3           1
# 4  1.613253e+09   0.002970             3           1
#
# [5 rows x 33 columns]

# %% [markdown]
# The `combo_type` column tells which telescope combination corresponds to the given event:
#
# * 0 = LST-1+M1
# * 1 = LST-1+M1+M2
# * 2 = LST-1+M2
# * 3 = M1+M2

# %% [markdown]
# ### Full analysis scenario
#
# When performing the full analysis, what you would do is to put all the MAGIC DL1b files from a given night and source in a directory. Then you would run `lst1_magic_event_coincidence` for each LST-1 DL1 file i.e. each subrun. This will give you a MAGIC+LST-1 DL1 file for each LST-1 subrun (assuming each has coincident events).
#
# At this point, one could use the auxiliary script `merge_hdf_files` to merge the DL1 files created in this step, so that there is just one DL1 file for each run. You would call it like this:
#
# ```
# merge_hdf_files -i <directory_with_dl1_files> -o <output_directory> --run-wise
# ```
#
# NB: you can use this also to merge together the MAGIC DL1 files for M1 and M2.

# %% [markdown]
# ## Stereo reconstruction
#
# The final step for this tutorial is stereo event reconstruction. For this, we use the `HillasReconstructor` class from `ctapipe`. From this, we get for each event the reconstrucyed direction of the primary particle in local coordinates (az, alt), core position, height of the shower maximum. We also add the impact parameter (closest distance between a shower axis and a telescope position).
#
# We use the `lst1_magic_stereo_reco` script.

# %%
out_stereo = "./output/dl1_stereo"
# !mkdir $out_stereo
# Out:
# mkdir: cannot create directory ‘./output/dl1_stereo’: File exists

# %%
dl1_input = f"{out_coincidence}/dl1_MAGIC_LST-1.Run03631.0000.h5"

# %% [markdown]
# From the configuration file, the relevant part is the following:
#
# ```
# stereo_reco:
#     quality_cuts: "(intensity > 50) & (width > 0)"
#     theta_uplim: "6 arcmin"
# ```
#
# i.e. some quality cuts will be applied to the events. `theta_uplim` specifies the maximum angular separation between telescope pointings to allow stereo reconstruction.

# %%
# !lst1_magic_stereo_reco -h
# Out:
# usage: lst1_magic_stereo_reco [-h] --input-file INPUT_FILE
#                               [--output-dir OUTPUT_DIR]
#                               [--config-file CONFIG_FILE] [--magic-only]
#
# options:
#   -h, --help            show this help message and exit
#   --input-file INPUT_FILE, -i INPUT_FILE
#                         Path to an input DL1 data file
#   --output-dir OUTPUT_DIR, -o OUTPUT_DIR
#                         Path to a directory where to save an output DL1-stereo
#                         data file
#   --config-file CONFIG_FILE, -c CONFIG_FILE
#                         Path to a configuration file
#   --magic-only          Reconstruct the stereo parameters using only MAGIC
#                         events

# %%
# !lst1_magic_stereo_reco -i $dl1_input -o $out_stereo -c $config_file
# Out:
# Input file: ./output/coincidence/dl1_MAGIC_LST-1.Run03631.0000.h5
#
# Is simulation: False
#
# Telescope positions:
#     1: <Quantity  -8.09 77.13  0.78  m>
#     2: <Quantity   39.3  -62.55  -0.97  m>
#     3: <Quantity  -31.21 -14.57   0.2   m>
#
# MAGIC-only analysis: False
#
# Quality cuts: (intensity > 50) & (width > 0)
#
# In total 1214 stereo events are found:
#     LST-1_MAGIC-I (type 0): 56 events (4.6%)
#     LST-1_MAGIC-I_MAGIC-II (type 1): 707 events (58.2%)
#     LST-1_MAGIC-II (type 2): 158 events (13.0%)
#     MAGIC-I_MAGIC-II (type 3): 293 events (24.1%)
#
# Checking the angular distances of the LST and MAGIC pointing directions...
# --> All the events were taken with smaller angular distances than the limit 6.0 arcmin.
#
# Reconstructing the stereo parameters...
# 0 events
# 100 events
# 200 events
# 300 events
# 400 events
# --> event 435 (event ID 25885) failed to reconstruct valid stereo parameters, maybe due to the images of zero width. Skipping...
# 500 events
# 600 events
# 700 events
# --> event 777 (event ID 44821) failed to reconstruct valid stereo parameters, maybe due to the images of zero width. Skipping...
# 800 events
# 900 events
# 1000 events
# 1100 events
# 1200 events
# 1214 events
#
# Output file: ./output/dl1_stereo/dl1_stereo_MAGIC_LST-1.Run03631.0000.h5
#
# Done.
#
# Process time: 20 [sec]

# %% [markdown]
# Note from the output:
#
# ```
# --> All the events were taken with smaller angular distances than the limit 6.0 arcmin.
# ```
#
# The poitings directions between the telescopes cannot be too different. This is a general problem for joint analysis, if the pointings are too far apart, it makes difficult (or impossible) to find some common regions of the sky to get the OFF events from.

# %% [markdown]
# ### Full analysis scenario
#
# In the full analysis scenario, instead of the single DL1 subrun file, you would run the script over the merged DL1 run file (see above).
